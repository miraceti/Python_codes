# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

# %%
x = symbols('x')

# %%
eq = 2*x**2 + 1

# %%
solve(eq,x)
# Out:
# [-sqrt(2)*I/2, sqrt(2)*I/2]

# %%
from sympy import *
var('x y')
eq0 = 2*x +10*y + 4
sympy.factor(eq0)
# Out:
# 2*(x + 5*y + 2)

# %%
from sympy import *
var('x y')
eq1 = x**2 - 4
sympy.factor(eq1)
# Out:
# (x - 2)*(x + 2)

# %%
from sympy import *
var('x y')
first = 2*x + 10
eq1 = Eq(first,0)
sol = solve(eq1,x)
print("x = ",sol[0])
# Out:
# x =  -5

# %%
from sympy import *
var('x y')
first = 2*x + 10
eq1 = Eq(first,y)
sol = solve(eq1,x)
print("x = ",sol[0])
# Out:
# x =  y/2 - 5

# %%
from sympy import *
var('x y')
eq1 = x**3 - 2*x**2 -5*x + 6
sympy.factor(eq1)
# Out:
# (x - 3)*(x - 1)*(x + 2)

# %%
def string_frac(in_string):
    if "/" in in_string:
        nd = in_string.split("/")
        n = float(nd[0])
        d = float(nd[1])
        ans = n/d
        return ans
    else:
        ans = float(in_string)
        return ans

# %%
string_frac("3")
# Out:
# 3.0

# %%
string_frac("2/5")
# Out:
# 0.4

# %%
def one_step_mult():
    import random
    a = random.randint(1,11)
    b = random.randint(2,24)
    print(a, "x= ", b)
    ans_in = (input("x = "))
    answer = b/a
    
    if string_frac(ans_in)==answer:
        print("Corrrect! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")

# %%
one_step_mult()
# Out:
# 6 x=  5
# x = 5/6
# Corrrect!

# %%
def one_step_add():
    import random
    a = random.randint(-4,10)
    b = random.randint(2,24)
    print("x + ",a, " = ", b)
    ans = float(input("x = "))
    answer = b-a
    
    if ans==answer:
        print("Corrrect! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")

# %%
one_step_add()
# Out:
# x +  6  =  7
# x = 1
# Corrrect!

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

eq = input('Enter equation: 0 = ')

solution = solve(eq,x)

for s in solution:
    print("x =",s)
# Out:
# Enter equation: 0 = 2*x+3
# x = -3/2

# %%
#10 X =  3.3333-
#   X =  .03333-
#------------
# 9 X = 3
#   X = 3/9

# %%
x = 5
y = 4*x + 3

print(x, ",",y)

print("x \t y")

for x in range(10):
    y = 4*x + 3
    print(x, "\t", y)
# Out:
# 5 , 23
# x 	 y
# 0 	 3
# 1 	 7
# 2 	 11
# 3 	 15
# 4 	 19
# 5 	 23
# 6 	 27
# 7 	 31
# 8 	 35
# 9 	 39

# %%
def f(x):
    y = 4*x + 3
    return y

print(5, ",",f(5))
# Out:
# 5 , 23

# %% [markdown]
# # GRAPHING

# %%
import matplotlib.pyplot as plt

#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

plt.plot([5],[4], 'ro')

plt.show()

# %%
import matplotlib.pyplot as plt

#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

for x in range(10):
    y = 0.5*x + 1
    plt.plot([x],[y], 'ro')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

y0 = x**2 - 6
plt.plot(x,y0, 'r')

y1 = x**2 + 6
plt.plot(x,y1, 'k')

y2 = 2*x + 1
plt.plot(x,y2, 'pink')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

#paramètres des axes
ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.set_title("some graph")
ax.grid(True)  #grille
ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
ax.set_yticks(np.arange(ymin,ymax,2))

y0 = x**2 - 6
plt.plot(x,y0, 'r')



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

#paramètres des axes
ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.set_title("some graph")
ax.grid(True)  #grille
ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
ax.set_yticks(np.arange(ymin,ymax,2))

y = 2*x + 1
plt.plot(x,y,label='y=2x+1')
plt.plot([4],[6], 'ro', label='point')
plt.plot(x, 3*x, label='steeper line')
plt.legend() #ici les labels sont repris dans le bloc legende


plt.show()

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

m = (y2 - y1) / (x2 - x1)

print("slope = ", m)
# Out:
# slope =  3.0

# %%
#LINEAR EQUATION

# %%
b = y1 - m*x1

print("y = ", m, "x + ", b)
# Out:
# y =  3.0 x +  4.0

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = 0 
y1 = 55
x2 = 2
y2 = 76

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)

xmin = 0
xmax = 10
ymin = 0
ymax = 150

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
#ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
#ax.set_yticks(np.arange(ymin,ymax,2))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  10.5 x +  55.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
x1 = 0 
y1 = 875
x2 = 1
y2 = 825

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)
print("in 5 years we have ",-50*5+875, " cas.")

x = symbols('x')
eq = 875 - 50*x
solution = solve(eq,x)
print("Le zéro sera atteint l'année " , int(solution[0]))

xmin = 0
xmax = 18
ymin = 0
ymax = 1000

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("cases")
ax.grid(True)
#ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
#ax.set_yticks(np.arange(ymin,ymax,2))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  -50.0 x +  875.0
# in 5 years we have  625  cas.
# Le zéro sera atteint l'année  17

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
x1 = 5 
y1 = 10
x2 = 25
y2 = 4

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)

xmin = 0
xmax = 40
ymin = 0
ymax = 15

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("profit")
ax.grid(True)
ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
ax.set_yticks(np.arange(ymin,ymax,1))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  -0.3 x +  11.5

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
x1 = 0 
y1 = 1700
x2 = 8
y2 = 2500

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)

xmin = 0
xmax = 10
ymin = 1500
ymax = 3000

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
#ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
#ax.set_yticks(np.arange(ymin,ymax,1))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  100.0 x +  1700.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve

t = symbols('t')
eq = -16*t**2 + 96*t
solution = solve(eq,t)
print("t = " , solution)
print("t1 = " , solution[0])
print("t2 = " , solution[1])
print(-16*3**2 + 96*3)
# Out:
# t =  [0, 6]
# t1 =  0
# t2 =  6
# 144

# %%
#MODULUS
print(5%3)
print(31%10)

number = 12

#find all factors
for test_factor in range(1, number +1):
    if number%test_factor == 0:
        print(test_factor)
# Out:
# 2
# 1
# 1
# 2
# 3
# 4
# 6
# 12

# %%
#reduce fraction to lowest terms
numerator = 12
denominator = 24
factor = 1

#find the greatest common factoe
for test_factor in range(1, denominator + 1):
    if numerator%test_factor == 0 and denominator%test_factor == 0:
        factor = test_factor

n = int(numerator/factor)
d = int(denominator/factor)

print("original : ", numerator, "/", denominator)
print("reduced", n, "/", d)
# Out:
# original :  12 / 24
# reduced 1 / 2

# %%
digit = input("entrez un nombre decimal a convertir : ")

exponent = int(len(digit) - 1)
n = float(digit)
numerator = int (n * 10**exponent)
denominator = 10**exponent

factor = 1
for test_factor in range(1, denominator + 1):
    if numerator%test_factor == 0 and denominator%test_factor == 0:
        factor = test_factor
        
num = int(numerator/factor)
den = int(denominator/factor)

print("La partie decimal est :", n)
print("La fraction est :", num, "/", den)
# Out:
# entrez un nombre decimal a convertir : 31.7
# La partie decimal est : 31.7
# La fraction est : 317 / 10

# %%
#factoring square roots

# %%
import math

print(math.sqrt(25))
print(math.sqrt(24))

n = 12

max_factor = 1

upper_limit = math.floor(math.sqrt(n)) + 1

for maybe_factor in range(1, upper_limit):
    if n % (maybe_factor**2) == 0:
        max_factor = maybe_factor
        
        
print("n = ", n)
print("square rooted factor = ", max_factor)
print("square factor = ", max_factor**2)
print("integer = ", n/max_factor**2)
# Out:
# 5.0
# 4.898979485566356
# n =  12
# square rooted factor =  2
# square factor =  4
# integer =  3.0

# %%
import math
import sympy
from sympy import symbols

n = 12

upper_limit = math.floor(math.sqrt(n)) + 1
max_factor = 1
other_factor = 1
square_root = 1

for maybe_factor in range(1, upper_limit):
    if n % (maybe_factor**2) == 0:
        max_factor = maybe_factor**2

other_factor = n/max_factor

square_root = int(math.sqrt(max_factor))
other_factor = int(other_factor)
output = square_root*sympy.sqrt(other_factor)

output
