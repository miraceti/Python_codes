# %% [markdown]
# # Résolution d'équations

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

# %%
x = symbols('x')

# %%
eq = 2*x**2 + 1

# %%
solve(eq,x)
# Out:
# [-sqrt(2)*I/2, sqrt(2)*I/2]

# %%
from sympy import *
var('x y')
eq0 = 2*x +10*y + 4
sympy.factor(eq0)
# Out:
# 2*(x + 5*y + 2)

# %%
from sympy import *
var('x y')
eq1 = x**2 - 4
sympy.factor(eq1)
# Out:
# (x - 2)*(x + 2)

# %%
from sympy import *
var('x y')
first = 2*x + 10
eq1 = Eq(first,0)
sol = solve(eq1,x)
print("x = ",sol[0])
# Out:
# x =  -5

# %%
from sympy import *
var('x y')
first = 2*x + 10
eq1 = Eq(first,y)
sol = solve(eq1,x)
print("x = ",sol[0])
# Out:
# x =  y/2 - 5

# %%
from sympy import *
var('x y')
eq1 = x**3 - 2*x**2 -5*x + 6
sympy.factor(eq1)
# Out:
# (x - 3)*(x - 1)*(x + 2)

# %%
def string_frac(in_string):
    if "/" in in_string:
        nd = in_string.split("/")
        n = float(nd[0])
        d = float(nd[1])
        ans = n/d
        return ans
    else:
        ans = float(in_string)
        return ans

# %%
string_frac("3")
# Out:
# 3.0

# %%
string_frac("2/5")
# Out:
# 0.4

# %%
def one_step_mult():
    import random
    a = random.randint(1,11)
    b = random.randint(2,24)
    print(a, "x= ", b)
    ans_in = (input("x = "))
    answer = b/a
    
    if string_frac(ans_in)==answer:
        print("Corrrect! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")

# %%
one_step_mult()
# Out:
# 3 x=  6
# x = 0
# Try again
# The correct answer is  2.0

# %%
def one_step_add():
    import random
    a = random.randint(-4,10)
    b = random.randint(2,24)
    print("x + ",a, " = ", b)
    ans = float(input("x = "))
    answer = b-a
    
    if ans==answer:
        print("Corrrect! \n")
    else:
        print("Try again")
        print("The correct answer is ", answer, "\n")

# %%
one_step_add()
# Out:
# x +  4  =  21
# x = 2
# Try again
# The correct answer is  17

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

eq = input('Enter equation: 0 = ')

solution = solve(eq,x)

for s in solution:
    print("x =",s)
# Out:
# Enter equation: 0 = 6

# %%
#10 X =  3.3333-
#   X =  .03333-
#------------
# 9 X = 3
#   X = 3/9

# %%
x = 5
y = 4*x + 3

print(x, ",",y)

print("x \t y")

for x in range(10):
    y = 4*x + 3
    print(x, "\t", y)
# Out:
# 5 , 23
# x 	 y
# 0 	 3
# 1 	 7
# 2 	 11
# 3 	 15
# 4 	 19
# 5 	 23
# 6 	 27
# 7 	 31
# 8 	 35
# 9 	 39

# %%
def f(x):
    y = 4*x + 3
    return y

print(5, ",",f(5))
# Out:
# 5 , 23

# %%
# Factor

# %%
import sympy
from sympy import *
import math

var('x y')

#Equation to factor
eq = x**3 - 2*x**2 - 5*x + 6

sympy.factor(eq)
# Out:
# (x - 3)*(x - 1)*(x + 2)

# %%
#solve for a variable

# %%
from sympy import *
import math

#identify all variables
var('a b c d x')

#gauche et droite du signe egal
left = 0
right = a*x**2 + b*x + c

#variable
variable = x

#sympy equation left = right
eq1 = Eq(left,right)

#sympy solve for that variable
sol = solve(eq1,variable)

#show factor result
for s in sol:
    print(variable, " = ",s)
# Out:
# x  =  (-b - sqrt(-4*a*c + b**2))/(2*a)
# x  =  (-b + sqrt(-4*a*c + b**2))/(2*a)

# %%
#slope-intercept equation from 2 points

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 0
x2 = 40
y2 = 13

#equation  y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ",m, "x + ",b)

#for the graph
xmin = 0
xmax = 100
ymin = 0
ymax = 50

#for the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

#basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #window size
plt.plot([xmin,xmax], [0,0], 'b') #blue x axis
plt.plot([0,0], [ymin,ymax], 'b') #blue y axis

#add details to the graph
ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.grid(True)
ax.set_xticks(np.arange(xmin, xmax, 6))
ax.set_yticks(np.arange(ymin, ymax, 3))

#plot the linear line as red line
plt.plot([xmin,xmax],[y3,y4],'r')

plt.show()
# Out:
# y =  0.325 x +  0.0

# %% [markdown]
# # GRAPHING

# %%
import matplotlib.pyplot as plt

#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

plt.plot([5],[4], 'ro')

plt.show()

# %%
import matplotlib.pyplot as plt

#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

for x in range(10):
    y = 0.5*x + 1
    plt.plot([x],[y], 'ro')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -20
xmax = 20
ymin = -20
ymax = 20
points = 20*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

y0 = x**2 - 6
plt.plot(x,y0, 'r')

y1 = x**2 + 6
plt.plot(x,y1, 'k')

y2 = 2*x + 1
plt.plot(x,y2, 'pink')

y3 = 3*x**3 + 1
plt.plot(x,y3, color='blue')
plt.fill_between(x, y3,10, facecolor='red')

y4 = x**2-7*x + 17
plt.plot(x, y4, color ='green')
plt.fill_between(x,y4,y2, facecolor='yellow')




plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

#paramètres des axes
ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.set_title("some graph")
ax.grid(True)  #grille
ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
ax.set_yticks(np.arange(ymin,ymax,2))

y0 = x**2 - 6
plt.plot(x,y0, 'r')



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#dimensions
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) #windows size
plt.plot([xmin,xmax],[0,0],'b') #axe x bleu
plt.plot([0,0],[ymin,ymax],'b') #axe y bleu

#paramètres des axes
ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.set_title("some graph")
ax.grid(True)  #grille
ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
ax.set_yticks(np.arange(ymin,ymax,2))

y = 2*x + 1
plt.plot(x,y,label='y=2x+1')
plt.plot([4],[6], 'ro', label='point')
plt.plot(x, 3*x, label='steeper line')
plt.legend() #ici les labels sont repris dans le bloc legende


plt.show()

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

m = (y2 - y1) / (x2 - x1)

print("slope = ", m)
# Out:
# slope =  3.0

# %%
#LINEAR EQUATION

# %%
b = y1 - m*x1

print("y = ", m, "x + ", b)
# Out:
# y =  3.0 x +  4.0

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = 0 
y1 = 55
x2 = 2
y2 = 76

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)

xmin = 0
xmax = 10
ymin = 0
ymax = 150

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
#ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
#ax.set_yticks(np.arange(ymin,ymax,2))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  10.5 x +  55.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
x1 = 0 
y1 = 875
x2 = 1
y2 = 825

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)
print("in 5 years we have ",-50*5+875, " cas.")

x = symbols('x')
eq = 875 - 50*x
solution = solve(eq,x)
print("Le zéro sera atteint l'année " , int(solution[0]))

xmin = 0
xmax = 18
ymin = 0
ymax = 1000

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("cases")
ax.grid(True)
#ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
#ax.set_yticks(np.arange(ymin,ymax,2))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  -50.0 x +  875.0
# in 5 years we have  625  cas.
# Le zéro sera atteint l'année  17

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
x1 = 5 
y1 = 10
x2 = 25
y2 = 4

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)

xmin = 0
xmax = 40
ymin = 0
ymax = 15

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("profit")
ax.grid(True)
ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
ax.set_yticks(np.arange(ymin,ymax,1))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  -0.3 x +  11.5

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
x1 = 0 
y1 = 1700
x2 = 8
y2 = 2500

m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1                     #equation : y = mx + b
print("y = ", m, "x + ", b)

xmin = 0
xmax = 10
ymin = 1500
ymax = 3000

y3 = m*xmin + b
y4 = m*xmax + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
#ax.set_xticks(np.arange(xmin,xmax,2)) #graduation axe x increment +2
#ax.set_yticks(np.arange(ymin,ymax,1))

plt.plot([xmin,xmax], [y3,y4], 'r')

plt.show()
# Out:
# y =  100.0 x +  1700.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve

t = symbols('t')
eq = -16*t**2 + 96*t
solution = solve(eq,t)
print("t = " , solution)
print("t1 = " , solution[0])
print("t2 = " , solution[1])
print(-16*3**2 + 96*3)
# Out:
# t =  [0, 6]
# t1 =  0
# t2 =  6
# 144

# %% [markdown]
# # MODULUS

# %%
print(5%3)
print(31%10)

number = 12

#find all factors
for test_factor in range(1, number +1):
    if number%test_factor == 0:
        print(test_factor)
# Out:
# 2
# 1
# 1
# 2
# 3
# 4
# 6
# 12

# %% [markdown]
# # reduce fraction to lowest terms

# %%
numerator = 12
denominator = 24
factor = 1

#find the greatest common factoe
for test_factor in range(1, denominator + 1):
    if numerator%test_factor == 0 and denominator%test_factor == 0:
        factor = test_factor

n = int(numerator/factor)
d = int(denominator/factor)

print("original : ", numerator, "/", denominator)
print("reduced", n, "/", d)
# Out:
# original :  12 / 24
# reduced 1 / 2

# %%
digit = input("entrez un nombre decimal a convertir : ")

exponent = int(len(digit) - 1)
n = float(digit)
numerator = int (n * 10**exponent)
denominator = 10**exponent

factor = 1
for test_factor in range(1, denominator + 1):
    if numerator%test_factor == 0 and denominator%test_factor == 0:
        factor = test_factor
        
num = int(numerator/factor)
den = int(denominator/factor)

print("La partie decimal est :", n)
print("La fraction est :", num, "/", den)
# Out:
# entrez un nombre decimal a convertir : 25
# La partie decimal est : 25.0
# La fraction est : 25 / 1

# %% [markdown]
# # factoring square roots

# %%
import math

print(math.sqrt(25))
print(math.sqrt(24))

n = 12

max_factor = 1

upper_limit = math.floor(math.sqrt(n)) + 1

for maybe_factor in range(1, upper_limit):
    if n % (maybe_factor**2) == 0:
        max_factor = maybe_factor
        
        
print("n = ", n)
print("square rooted factor = ", max_factor)
print("square factor = ", max_factor**2)
print("integer = ", n/max_factor**2)
# Out:
# 5.0
# 4.898979485566356
# n =  12
# square rooted factor =  2
# square factor =  4
# integer =  3.0

# %%
import math
import sympy
from sympy import symbols

n = 12

upper_limit = math.floor(math.sqrt(n)) + 1
max_factor = 1
other_factor = 1
square_root = 1

for maybe_factor in range(1, upper_limit):
    if n % (maybe_factor**2) == 0:
        max_factor = maybe_factor**2

other_factor = n/max_factor

square_root = int(math.sqrt(max_factor))
other_factor = int(other_factor)
output = square_root*sympy.sqrt(other_factor)

output
# Out:
# 2*sqrt(3)

# %% [markdown]
# # Fonction avec 2 entrées

# %%
def add(a,b):
    sum = a+b
    print("La somme est : ", sum)
    
first = float(input("Entrer un nombre:\n"))
second = float(input("Entrer un second nombre:\n"))

add(first,second)
# Out:
# Entrer un nombre:
# 36
# Entrer un second nombre:
# 5
# La somme est :  41.0

# %% [markdown]
# # Fonction avec valeur de retour

# %%
def multiplied(number):
    return number*2

a = float(input("Entrer un nombre: \n"))
print("le nombre multiplié est ", multiplied(a))
# Out:
# Entrer un nombre:
# 25
# le nombre multiplié est  50.0

# %% [markdown]
# # Equation de x

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

eq = input("Entrer une équation à résoudre pour x: 0 =")
print("x = ", solve(eq,x)[0])#on ne prend que le première solution même si il y en a 2
print("x = ", solve(eq,x))#on prend toutes les solutions
# Out:
# Entrer une équation à résoudre pour x: 0 =2*x-5
# x =  5/2
# x =  [5/2]

# %% [markdown]
# # Interactive graphs

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def f(m, b, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10*(xmax-xmin)
    x = np.linspace(xmin, xmax, points)
    
    plt.axis([xmin,xmax,ymin,ymax])#windows size
    plt.plot([xmin,xmax],[0,0],'k') # black x axis
    plt.plot([0,0],[ymin,ymax],'k') # black y axis
    plt.title('y = mx + b')
    
    plt.plot(x, m*x+b)
    plt.show()
    
#les sliders
interactive_plot = interactive(f, m=(-9, 9), b=(-9, 9), zoom=(1, 100) )
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='m', max=9, min=-9), IntSlider(value=0, description='b', …

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def f(zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10*(xmax-xmin)
    x = np.linspace(xmin, xmax, points)
    
    fig, ax = plt.subplots()
    plt.axis([xmin,xmax,ymin,ymax])#windows size
    plt.plot([xmin,xmax],[0,0],'black') # black x axis
    plt.plot([0,0],[ymin,ymax],'black') # black y axis
    
    #line 1
    y1 = 3*x**2 -4
    plt.plot(x, y1)
    plt.fill_between(x, y1, ymax, facecolor='green')
    
    #line 2
    y2 = x
    plt.plot(x, y2)
    plt.fill_between(x, y2, ymin, facecolor='blue')
    
    ax.set_xlabel("x_values")
    ax.set_ylabel("y_values")
    ax.set_title("some graph")
    ticks = int(round((xmax-xmin)/20))
    ax.set_xticks(np.arange(xmin, xmax, ticks))
    ax.set_yticks(np.arange(ymin, ymax, ticks))
    ax.grid(True)
    plt.show()
    
#les sliders
interactive_plot = interactive(f,  zoom=(1, 100) )
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='zoom', min=1), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# # Graphing weather data (pip intall meteostat)

# %%
#importer meteostat libraries
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

#doc : https://dev.meteostat.net/python/daily.html#data-structure
#columns : time,tavg,tmin,tmax,prcp,snow,wdir,wspd,wpgt,pres,tsun

#set time period
start = datetime(2022, 1, 1)
end = datetime(2022, 12, 31)


#create point for Vancouver, BC, or Philadelphia, PA
vancouver = Point(49.2497, -123.1193, 100)#lattitude, longitude,altitude
#philly = Point(39.97 -75.13, 25)
#paris = Point(42.52,2.19,10)

#get daily data for 2022
data = Daily(vancouver, start, end)
data = data.fetch()
print(data)

if len(data) > 0:
#plot line chart including average, minimum and maximum temperature
    data.plot(y=['tavg','tmin','tmax'])
    plt.show()
# Out:
# ...
#             tavg  tmin  tmax  prcp   snow   wdir  wspd   wpgt    pres  tsun
# time
# 2022-01-01  -0.6  -4.4   3.2   0.0    0.0   64.0  11.5   49.0  1020.2   NaN
# 2022-01-02   2.8   0.1   5.4  12.2  100.0   64.0  17.3   68.0  1004.8   NaN
# 2022-01-03   3.5   2.0   5.1  10.0    0.0   78.0  12.4   62.0   997.9   NaN
# 2022-01-04   2.2  -0.2   4.6  19.3    0.0   58.0  11.3   46.0  1012.9   NaN
# 2022-01-05  -0.6  -2.5   1.3   0.7    0.0   47.0   6.0    NaN  1020.2   NaN
# ...          ...   ...   ...   ...    ...    ...   ...    ...     ...   ...
# 2022-12-27   7.8   6.3   9.3  37.2    NaN   78.0  14.2  165.6   982.9   NaN
# 2022-12-28   6.3   4.8   7.7   6.0    NaN  249.0   8.2  165.6  1005.6   NaN
# 2022-12-29   5.1   4.1   6.1   4.4    NaN   63.0  12.8  118.8  1002.7   NaN
# 2022-12-30   7.0   5.0   9.1  18.2    NaN   78.0  11.4  140.4   997.8   NaN
# 2022-12-31   6.1   4.4   7.7   3.4    NaN  105.0   5.7  126.0  1008.9   NaN
#
# [365 rows x 10 columns]

# %% [markdown]
# # Système d'équation 1

# %%
from sympy import *

x,y = symbols('x y')

#equation set to 0
first = 2*x + y - 1
second = x - 2*y + 7

print(linsolve([first, second], (x,y)))
# Out:
# {(-1, 3)}

# %% [markdown]
# # Système d'équation 2

# %%
from sympy import *

x,y = symbols('x y')

#equation set to 0
first = 2*x + y - 1
second = x - 2*y + 7

#parse the finite set as coordonate pair
solution = linsolve([first, second], (x,y))
x_solution = solution.args[0][0]
y_solution = solution.args[0][1]

print("(", x_solution, ",", y_solution, ")")
# Out:
# ( -1 , 3 )

# %% [markdown]
# # factor change from "0 =" to "y =" to graph

# %%
from sympy import *
from sympy.plotting import plot

var('x y')

first = 2*x + y - 1
second = x - 2*y + 7

solution = linsolve([first, second], (x,y))
x_solution = solution.args[0][0]
y_solution = solution.args[0][1]

print("(", x_solution, ",", y_solution, ")")

#sympy syntax for equation equal to 0
y_first = Eq(first, 0)

#sympy solve for y
y1 = solve(y_first,y)

#sympy syntax for equation equal to 0
y_second = Eq(second, 0)

#sympy solve for y
y2 = solve(y_second,y)

#show factored results
print("y = ", y1[0])
print("y = ", y2[0])

#plot solution
x = symbols('x')
plot(y1[0], y2[0], (x, -10, 10))


#astuce pour avoir la même echelle en x et y pour voir la perpendicularité
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 5, 10
plot(y1[0], y2[0], (x, -10, 10))
# Out:
# ( -1 , 3 )
# y =  1 - 2*x
# y =  x/2 + 7/2

# %%
# Solve and graph a system equation

# %%
from sympy import *
from sympy.plotting import plot
from sympy import sqrt

var('x y')

#first equation set equal to 0
first = -x**2 - y + 10
#first = sqrt(x) - y

#second equation set equal to 0
second = 2*x**2 - 2*y - 4
#second = -x + 5  y

#solve can be linear or nonlinear equation
solution = nonlinsolve([first, second], (x, y))
for a in range(len(solution.args)):
    x_solution = solution.args[a][0]
    y_solution = solution.args[a][1]
    print("solution - ()", x_solution, ",", y_solution, ")")
    
    
#sympy syntax for equation equal to 0
y_first = Eq(first,0)

#sympy solve for y
y1 = solve(y_first, y)

#same 2 steps for second equation
y_second = Eq(second,0)
y2 = solve(y_second, y)

#show factored results
print("y = ", y1[0])
print("y = ", y2[0])

#plot solution
x = symbols('x')
xmin = -10
xmax = 10
plot(y1[0], y2[0], (x, xmin, xmax))
# Out:
# solution - () sqrt(6) , 4 )
# solution - () -sqrt(6) , 4 )
# y =  10 - x**2
# y =  x**2 - 2

# %%
# equation avec des points x et y donnés

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def f(zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10*(xmax-xmin)
    #x = np.linspace(xmin, xmax, points)
    x = [0, 5, 10, 15]
    
    fig, ax = plt.subplots()
    plt.axis([xmin,xmax,ymin,ymax])#windows size
    plt.plot([xmin,xmax],[0,0],'black') # black x axis
    plt.plot([0,0],[ymin,ymax],'black') # black y axis
    
    #line 1
    #y1 = 3*x**2 -4
    y1 = [5, -10, -25, -40]
    plt.plot(x, y1, 'ro')
    #plt.fill_between(x, y1, ymax, facecolor='green')
    
    #line 2
    #y2 = x
    #plt.plot(x, y2)
    #plt.fill_between(x, y2, ymin, facecolor='blue')
    
    ax.set_xlabel("x_values")
    ax.set_ylabel("y_values")
    ax.set_title("some graph")
    ticks = int(round((xmax-xmin)/20))
    ax.set_xticks(np.arange(xmin, xmax, ticks))
    ax.set_yticks(np.arange(ymin, ymax, ticks))
    ax.grid(True)
    plt.show()
    
#les sliders
interactive_plot = interactive(f,  zoom=(1, 100) )
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='zoom', min=1), Output()), _dom_classes=('widget-interac…
