# %%
from bs4 import BeautifulSoup
import requests
import openpyxl

excel = openpyxl.Workbook()
print(excel.sheetnames)

sheet = excel.active
sheet.title = ' Top rated movies'
print(excel.sheetnames)

#headings columns
sheet.append(['Movie num','Movie name'])
# Out:
# ['Sheet']
# [' Top rated movies']

# %%
try:
    source = requests.get(
        'https://fr.wikipedia.org/wiki/Liste_de_films_fran%C3%A7ais_sortis_en_2022'
                        )
    source.raise_for_status()
    
    soup = BeautifulSoup(source.text, 'html.parser')
    #print(soup)
    
    tablefilm = soup.find('table', class_="wikitable sortable")
    #print(tablefilm)   
    
    #movies = soup.find('tbody', class_="nomclass")
    movies = soup.find('tbody')#the first match et pas de class
    #print(movies)
    
    #tous les TR tag
    movies_list = soup.find('tbody').find_all('tr')
    print("\n***************LEn MOVIES LIST*******************************\n")
    #print(len(movies_list))
    print("\n***************MOVIES LIST*******************************\n")
    #print(movies_list)
    
    nblignes = len(movies_list)
    
    print("\n\n\n***************MOVIES LIST 10*******************************\n")
    print(movies_list[10])
    film = movies_list[10]
    print("\n\n\n***************MOVIES LIST*******************************\n")
    #for movie in movies_list:
        #print(movie)
    print("\n\n\n***************MOVIE bloc*******************************\n")    
    name = film.find('td').a
    print("name : ", name)
    
    print("\n\n\n***************MOVIES name href*******************************\n")
    name = film.find('td').a
    print("name : ", name)
    
    print("\n\n\n***************MOVIES name text*******************************\n")
    name_text = film.find('td').a.text
    print("name_text : ", name_text)
    
    print("\n\n\n***************MOVIE  text*******************************\n")
    nametext = film.find('td').text
    print("nametext : ", nametext)
    
    print("\n\n\n***************MOVIE  gettext*******************************\n")
    get_text = film.find('td').get_text(strip=True)
    print("get_text : ", get_text)
    
    #split
    get_text_split = film.find('td').get_text(strip=True).split('.')
    print("get_text_split : ", get_text_split)
    
    get_text_split0 = film.find('td').get_text(strip=True).split('.')[0]
    print("get_text_split0 : ", get_text_split0)
    
    #si year= (1994)
    #get_year = film.find('td').span.text.strip('()')
    #print("get_year : ", get_year) ==> 1994
    
    #"on boucle sur tutes les lignes"
    
    for n in range(1,nblignes):
        print(n)
        film_n = movies_list[n]
        #print(film_n)
        namen = film_n.find('td').a
        #print("name : ", namen)
        name_text_n = film_n.find('td').a.text
        print("name_text : ", name_text_n)
        sheet.append([n,name_text_n])
    
except Exception as e:
    print(e)
    
excel.save('imdb2.xlsx')
# Out:
# ***************LEn MOVIES LIST*******************************
#
#
# ***************MOVIES LIST*******************************
#
#
#
#
# ***************MOVIES LIST 10*******************************
#
# <tr>
# <td><a href="/wiki/Babysitter_(film)" title="Babysitter (film)"><i>Babysitter</i></a>
# </td>
# <td><a href="/wiki/Monia_Chokri" title="Monia Chokri">Monia Chokri</a>
# </td>
# <td>Comédie
# </td>
# <td><a href="/wiki/Patrick_Hivon" title="Patrick Hivon">Patrick Hivon</a>, <a href="/wiki/Monia_Chokri" title="Monia Chokri">Monia Chokri</a>, <a href="/wiki/Nadia_Tereszkiewicz" title="Nadia Tereszkiewicz">Nadia Tereszkiewicz</a>, <a href="/wiki/Steve_Laplante" title="Steve Laplante">Steve Laplante</a>
# </td></tr>
#
#
#
# ***************MOVIES LIST*******************************
#
#
#
#
# ***************MOVIE bloc*******************************
#
# name :  <a href="/wiki/Babysitter_(film)" title="Babysitter (film)"><i>Babysitter</i></a>
#
#
#
# ***************MOVIES name href*******************************
#
# name :  <a href="/wiki/Babysitter_(film)" title="Babysitter (film)"><i>Babysitter</i></a>
#
#
#
# ***************MOVIES name text*******************************
#
# name_text :  Babysitter
#
#
#
# ***************MOVIE  text*******************************
#
# nametext :  Babysitter
#
#
#
#
# ***************MOVIE  gettext*******************************
#
# get_text :  Babysitter
# get_text_split :  ['Babysitter']
# get_text_split0 :  Babysitter
# 1
# name_text :  La Malédiction des Dunois
# 2
# name_text :  Athena
# 3
# name_text :  La Nuit du 12
# 4
# name_text :  La Vraie Famille
# 5
# name_text :  Un autre monde
# 6
# name_text :  Revoir Paris
# 7
# name_text :  À plein temps
# 8
# name_text :  Bruno Reidal
# 9
# name_text :  Sentinelle sud
# 10
# name_text :  Babysitter
# 11
# name_text :  En attendant Bojangles
# 12
# name_text :  Les Enfants des autres
# 13
# name_text :  Icare
# 14
# name_text :  L'Origine du mal
# 15
# name_text :  Twist à Bamako
# 16
# name_text :  Les Promesses
# 17
# name_text :  La Revanche des Crevettes pailletées
# 18
# name_text :  Incroyable mais vrai
# 19
# name_text :  Les Cinq Diables
# 20
# name_text :  Goliath
# 21
# name_text :  Petite Nature
# 22
# name_text :  Mes frères et moi
# 23
# name_text :  Une jeune fille qui va bien
# 24
# name_text :  Les Secrets de mon père
# 25
# name_text :  De nos frères blessés
# 26
# name_text :  Peter von Kant
# 27
# name_text :  Inexorable
# 28
# name_text :  Coupez !
# 29
# name_text :  Mi iubita, mon amour
# 30
# name_text :  Vaillante
# 31
# name_text :  En roue libre
# 32
# name_text :  Arthur Rambo
# 33
# name_text :  Irréductible
# 34
# name_text :  Enquête sur un scandale d'État
# 35
# name_text :  Rodéo
# 36
# name_text :  Le Monde d'hier
# 37
# name_text :  Ouistreham
# 38
# name_text :  After Blue (Paradis sale)
# 39
# name_text :  Kompromat
# 40
# name_text :  La Colline où rugissent les lionnes
# 41
# name_text :  Azuro
# 42
# name_text :  Les Meilleures
# 43
# name_text :  Petite Fleur
# 44
# name_text :  La Place d'une autre
# 45
# name_text :  Viens je t'emmène
# 46
# name_text :  En corps
# 47
# name_text :  Placés
# 48
# name_text :  Clèves
# 49
# name_text :  Les Vedettes
# 50
# name_text :  Adieu monsieur Haffmann
# 51
# name_text :  Le Visiteur du futur
# 52
# name_text :  Big Bug
# 53
# name_text :  L'Année du requin
# 54
# name_text :  Le Monde après nous
# 55
# name_text :  Memory Box
# 56
# name_text :  Frère et Sœur
# 57
# name_text :  Rien à foutre
# 58
# name_text :  Ima
# 59
# name_text :  L'Homme parfait
# 60
# name_text :  Les Liaisons dangereuses
# 61
# name_text :  Mascarade
# 62
# name_text :  Couleurs de l'incendie
# 63
# name_text :  Le Nouveau Jouet
# 64
# name_text :  Le Pharaon, le Sauvage et la Princesse
# 65
# name_text :  Simone, le voyage du siècle
# 66
# name_text :  L'Innocent
# 67
# name_text :  Le Petit Nicolas : Qu'est-ce qu'on attend pour être heureux ?
# 68
# name_text :  Les Harkis
# 69
# name_text :  Novembre
# 70
# name_text :  Stella est amoureuse
# 71
# name_text :  Falcon Lake
# 72
# name_text :  Nos frangins
# 73
# name_text :  Annie colère
# 74
# name_text :  Fumer fait tousser
# 75
# name_text :  Le Lycéen
# 76
# name_text :  Saint Omer
# 77
# name_text :  Entre les vagues
# 78
# name_text :  Charlotte
# 79
# name_text :  Plus que jamais
# 80
# name_text :  Les Amandiers
# 81
# name_text :  Balle perdue 2
# 82
# name_text :  Ogre
# 83
# name_text :  L'Été nucléaire
# 84
# 'NoneType' object has no attribute 'text'
