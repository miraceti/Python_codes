# %%
import pandas as pd

# %%
day_one_trips = pd.read_csv("2021_Green_Taxi_Trip_Data.csv")
day_one_trips
# Out:
# /tmp/ipykernel_35259/1352520779.py:1: DtypeWarning: Columns (8,9,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   day_one_trips = pd.read_csv("2021_Green_Taxi_Trip_Data.csv")
#          VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0             2.0  01/01/2021 12:15:56 AM  01/01/2021 12:19:52 AM
# 1             2.0  01/01/2021 12:25:59 AM  01/01/2021 12:34:44 AM
# 2             2.0  01/01/2021 12:45:57 AM  01/01/2021 12:51:55 AM
# 3             2.0  12/31/2020 11:57:51 PM  01/01/2021 12:04:56 AM
# 4             2.0  01/01/2021 12:16:36 AM  01/01/2021 12:16:40 AM
# ...           ...                     ...                     ...
# 1048570       2.0  12/05/2021 11:29:00 AM  12/05/2021 11:58:00 AM
# 1048571       2.0  12/05/2021 11:13:00 AM  12/05/2021 11:54:00 AM
# 1048572       2.0  12/05/2021 11:51:00 AM  12/05/2021 11:54:00 AM
# 1048573       2.0  12/05/2021 11:44:00 AM  12/05/2021 11:47:00 AM
# ...

# %%
day_one_trips0 = day_one_trips[(day_one_trips["lpep_pickup_datetime"] >= "01/01/2021") &                      
                      (day_one_trips["lpep_pickup_datetime"] < "01/02/2021")]
day_one_trips0
# Out:
#        VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0           2.0  01/01/2021 12:15:56 AM  01/01/2021 12:19:52 AM
# 1           2.0  01/01/2021 12:25:59 AM  01/01/2021 12:34:44 AM
# 2           2.0  01/01/2021 12:45:57 AM  01/01/2021 12:51:55 AM
# 4           2.0  01/01/2021 12:16:36 AM  01/01/2021 12:16:40 AM
# 5           2.0  01/01/2021 12:16:36 AM  01/01/2021 12:16:40 AM
# ...         ...                     ...                     ...
# 46014       NaN  01/01/2021 10:44:00 PM  01/01/2021 10:59:00 PM
# 46015       NaN  01/01/2021 10:03:00 PM  01/01/2021 10:35:00 PM
# 46016       NaN  01/01/2021 10:08:00 PM  01/01/2021 10:42:00 PM
# 46017       NaN  01/01/2021 11:21:00 PM  01/01/2021 11:31:00 PM
# 46018       NaN  01/01/2021 11:29:00 PM  01/01/2021 11:54:00 PM
#
#       store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                      N         1.0            43           151
# ...

# %%
day_one_trips.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
day_one_trips1 = day_one_trips0 [["lpep_pickup_datetime",
                                             "lpep_dropoff_datetime",
                                             "passenger_count",
                                             "trip_distance",
                                             "PULocationID"
                                ]]
day_one_trips1
# Out:
#          lpep_pickup_datetime   lpep_dropoff_datetime  passenger_count  \
# 0      01/01/2021 12:15:56 AM  01/01/2021 12:19:52 AM              1.0
# 1      01/01/2021 12:25:59 AM  01/01/2021 12:34:44 AM              1.0
# 2      01/01/2021 12:45:57 AM  01/01/2021 12:51:55 AM              1.0
# 4      01/01/2021 12:16:36 AM  01/01/2021 12:16:40 AM              3.0
# 5      01/01/2021 12:16:36 AM  01/01/2021 12:16:40 AM              3.0
# ...                       ...                     ...              ...
# 46014  01/01/2021 10:44:00 PM  01/01/2021 10:59:00 PM              NaN
# 46015  01/01/2021 10:03:00 PM  01/01/2021 10:35:00 PM              NaN
# 46016  01/01/2021 10:08:00 PM  01/01/2021 10:42:00 PM              NaN
# 46017  01/01/2021 11:21:00 PM  01/01/2021 11:31:00 PM              NaN
# 46018  01/01/2021 11:29:00 PM  01/01/2021 11:54:00 PM              NaN
#
#       trip_distance  PULocationID
# 0              1.01            43
# 1              2.53           166
# ...

# %%
day_two_trips2 = day_one_trips[(day_one_trips["lpep_pickup_datetime"] >= "01/02/2021") &                      
                      (day_one_trips["lpep_pickup_datetime"] < "01/03/2021")]
day_two_trips2
# Out:
#        VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 634         2.0  01/02/2021 12:14:34 AM  01/02/2021 12:19:53 AM
# 635         2.0  01/02/2021 12:21:20 AM  01/02/2021 12:52:01 AM
# 636         1.0  01/02/2021 12:09:02 AM  01/02/2021 12:15:59 AM
# 637         1.0  01/02/2021 12:48:21 AM  01/02/2021 01:06:31 AM
# 638         2.0  01/02/2021 12:56:04 AM  01/02/2021 12:57:18 AM
# ...         ...                     ...                     ...
# 55985       NaN  01/02/2021 11:31:00 PM  01/02/2021 11:42:00 PM
# 55986       NaN  01/02/2021 11:12:00 PM  01/02/2021 11:37:00 PM
# 55987       NaN  01/02/2021 11:55:00 PM  01/03/2021 12:18:00 AM
# 55988       NaN  01/02/2021 11:53:00 PM  01/03/2021 12:30:00 AM
# 55989       NaN  01/02/2021 11:11:00 PM  01/02/2021 11:26:00 PM
#
#       store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 634                    N         1.0            42           244
# ...

# %%
#merge join concat
#merge
#day_one_trip.merge(zone, left_on= "PULocationID", right_on="locationID", how="left")

#join
#day_one_trip.join(zones, how="left" , on="PULocationID")

#concat
#   pd.concat([day_one_trips, day_two_trips], ignore_index =  True)
