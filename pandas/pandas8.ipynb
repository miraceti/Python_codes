# %%
import pandas as pd
import numpy as np

data = pd.read_csv("NYC_Jobs.csv")
data.head()
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0  559432   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1  584642    DEPARTMENT OF BUSINESS SERV.     External               1
# 2  578078   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 3  590587  CONSUMER AND WORKER PROTECTION     External               1
# 4  572710               POLICE DEPARTMENT     Internal               1
#
#                                       Business Title  \
# 0  Laboratory Informatics Specialist, Bureau of t...
# 1                    DIRECTOR FOR OUTCOME VALIDATION
# 2  SSP Data Manager, Bureau of Alcohol and Drug U...
# 3                       Senior Legal Staff Associate
# 4                      Procurement Analyst, Level II
#
#               Civil Service Title Title Classification Title Code No Level  \
# 0         CITY RESEARCH SCIENTIST    Non-Competitive-5         21744    03
# 1  ADMIN COMMUNITY RELATIONS SPEC        Competitive-1         1002F    00
# 2         CITY RESEARCH SCIENTIST    Non-Competitive-5         21744    02
# 3              CLERICAL ASSOCIATE        Competitive-1         10251    04
# 4             PROCUREMENT ANALYST        Competitive-1         12158    02
#
#                                         Job Category  ...  \
# 0  Constituent Services & Community Programs Heal...  ...
# 1          Constituent Services & Community Programs  ...
# 2                 Health Policy, Research & Analysis  ...
# 3                                      Legal Affairs  ...
# 4                 Finance, Accounting, & Procurement  ...
#
#                               Additional Information  \
# 0  **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
# 1                                                NaN
# 2  **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
# 3  In addition, the NYC Department of Consumer an...
# 4                                                NaN
#
#                                             To Apply  Hours/Shift  \
# 0  Apply online with a cover letter to https://a1...          NaN
# 1  THIS POSITION IS OPEN TO CANDIDATES WHO ARE IN...          NaN
# 2  Apply online with a cover letter to https://a1...          NaN
# 3  For Non-City/External Candidates: Visit the Ex...          NaN
# 4                                 Please Click Apply       9 to 5
#
#                                      Work Location 1 Recruitment Contact  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4  375 Pearl Street, Suite 15-207, New York, NY  ...                 NaN
#
#                                Residency Requirement Posting Date  \
# 0  New York City residency is generally required ...   04/17/2023
# 1  New York City residency is generally required ...   06/22/2023
# 2  New York City residency is generally required ...   07/05/2023
# 3  New York City residency is generally required ...   06/21/2023
# 4  New York City residency is generally required ...   07/03/2023
#
#     Post Until Posting Updated Process Date
# 0  07-NOV-2023      04/17/2023   07/11/2023
# 1  20-SEP-2023      06/22/2023   07/11/2023
# 2  02-NOV-2023      07/05/2023   07/11/2023
# 3  11-AUG-2023      06/21/2023   07/11/2023
# 4  02-AUG-2023      07/06/2023   07/11/2023
#
# [5 rows x 30 columns]

# %%
#map  vs apply vs applymap
#apply
def capitalize(title):
    return title.lower().capitalize()

data["Civil Service Title"].apply(capitalize)
# Out:
# 0              City research scientist
# 1       Admin community relations spec
# 2              City research scientist
# 3                   Clerical associate
# 4                  Procurement analyst
#                      ...
# 6239                   Agency attorney
# 6240                   Agency attorney
# 6241    Administrative  program office
# 6242         Associate project manager
# 6243           City research scientist
# Name: Civil Service Title, Length: 6244, dtype: object

# %%
#applymap
def add_year(text):
    return str(text) + "_2022"

data.applymap(add_year)
# Out:
#            Job ID                               Agency   Posting Type  \
# 0     559432_2022   DEPT OF HEALTH/MENTAL HYGIENE_2022  External_2022
# 1     584642_2022    DEPARTMENT OF BUSINESS SERV._2022  External_2022
# 2     578078_2022   DEPT OF HEALTH/MENTAL HYGIENE_2022  External_2022
# 3     590587_2022  CONSUMER AND WORKER PROTECTION_2022  External_2022
# 4     572710_2022               POLICE DEPARTMENT_2022  Internal_2022
# ...           ...                                  ...            ...
# 6239  590893_2022  CONSUMER AND WORKER PROTECTION_2022  External_2022
# 6240  590545_2022         DEPARTMENT OF BUILDINGS_2022  Internal_2022
# 6241  585054_2022        DEPARTMENT FOR THE AGING_2022  Internal_2022
# 6242  582278_2022    DEPARTMENT OF TRANSPORTATION_2022  External_2022
# 6243  575105_2022        DEPARTMENT FOR THE AGING_2022  Internal_2022
#
#      # Of Positions                                     Business Title  \
# 0            1_2022  Laboratory Informatics Specialist, Bureau of t...
# 1            1_2022               DIRECTOR FOR OUTCOME VALIDATION_2022
# 2            1_2022  SSP Data Manager, Bureau of Alcohol and Drug U...
# 3            1_2022                  Senior Legal Staff Associate_2022
# 4            1_2022                 Procurement Analyst, Level II_2022
# ...             ...                                                ...
# 6239         1_2022                                 Staff Counsel_2022
# 6240         1_2022                        Assistant Code Counsel_2022
# 6241         1_2022                  Director, Program Operations_2022
# 6242         1_2022                     Associate Project Manager_2022
# 6243         1_2022                     Senior Research Associate_2022
#
#                       Civil Service Title    Title Classification  \
# 0            CITY RESEARCH SCIENTIST_2022  Non-Competitive-5_2022
# 1     ADMIN COMMUNITY RELATIONS SPEC_2022      Competitive-1_2022
# 2            CITY RESEARCH SCIENTIST_2022  Non-Competitive-5_2022
# 3                 CLERICAL ASSOCIATE_2022      Competitive-1_2022
# 4                PROCUREMENT ANALYST_2022      Competitive-1_2022
# ...                                   ...                     ...
# 6239                 AGENCY ATTORNEY_2022  Non-Competitive-5_2022
# 6240                 AGENCY ATTORNEY_2022  Non-Competitive-5_2022
# 6241  ADMINISTRATIVE  PROGRAM OFFICE_2022      Competitive-1_2022
# 6242       ASSOCIATE PROJECT MANAGER_2022      Competitive-1_2022
# 6243         CITY RESEARCH SCIENTIST_2022  Non-Competitive-5_2022
#
#      Title Code No    Level  \
# 0       21744_2022  03_2022
# 1       1002F_2022  00_2022
# 2       21744_2022  02_2022
# 3       10251_2022  04_2022
# 4       12158_2022  02_2022
# ...            ...      ...
# 6239    30087_2022  02_2022
# 6240    30087_2022  03_2022
# 6241    10084_2022  M1_2022
# 6242    22427_2022  02_2022
# 6243    21744_2022  03_2022
#
#                                            Job Category  ...  \
# 0     Constituent Services & Community Programs Heal...  ...
# 1        Constituent Services & Community Programs_2022  ...
# 2               Health Policy, Research & Analysis_2022  ...
# 3                                    Legal Affairs_2022  ...
# 4               Finance, Accounting, & Procurement_2022  ...
# ...                                                 ...  ...
# 6239                                 Legal Affairs_2022  ...
# 6240                                 Legal Affairs_2022  ...
# 6241  Constituent Services & Community Programs Soci...  ...
# 6242         Engineering, Architecture, & Planning_2022  ...
# 6243  Constituent Services & Community Programs Comm...  ...
#
#                                  Additional Information  \
# 0     **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
# 1                                              nan_2022
# 2     **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
# 3     In addition, the NYC Department of Consumer an...
# 4                                              nan_2022
# ...                                                 ...
# 6239  In addition, the NYC Department of Consumer an...
# 6240  The proposed salary for this position is $91,5...
# 6241                                           nan_2022
# 6242  The City of New York is an inclusive equal opp...
# 6243  As a current or prospective employee of the Ci...
#
#                                                To Apply    Hours/Shift  \
# 0     Apply online with a cover letter to https://a1...       nan_2022
# 1     THIS POSITION IS OPEN TO CANDIDATES WHO ARE IN...       nan_2022
# 2     Apply online with a cover letter to https://a1...       nan_2022
# 3     For Non-City/External Candidates: Visit the Ex...       nan_2022
# 4                               Please Click Apply_2022    9 to 5_2022
# ...                                                 ...            ...
# 6239  For Non-City/External Candidates: Visit the Ex...       nan_2022
# 6240  For Non-City/External Candidates: Visit the Ex...       nan_2022
# 6241  Please be sure to submit a resume & cover lett...       nan_2022
# 6242  Resumes may be submitted electronically using ...  35 Hours_2022
# 6243  Please be sure to submit a resume & cover lett...       nan_2022
#
#                                         Work Location 1 Recruitment Contact  \
# 0                                              nan_2022            nan_2022
# 1                                              nan_2022            nan_2022
# 2                                              nan_2022            nan_2022
# 3                                              nan_2022            nan_2022
# 4     375 Pearl Street, Suite 15-207, New York, NY  ...            nan_2022
# ...                                                 ...                 ...
# 6239                                           nan_2022            nan_2022
# 6240                                           nan_2022            nan_2022
# 6241                                           nan_2022            nan_2022
# 6242                             55 Water St Ny Ny_2022            nan_2022
# 6243                                           nan_2022            nan_2022
#
#                                   Residency Requirement     Posting Date  \
# 0     New York City residency is generally required ...  04/17/2023_2022
# 1     New York City residency is generally required ...  06/22/2023_2022
# 2     New York City residency is generally required ...  07/05/2023_2022
# 3     New York City residency is generally required ...  06/21/2023_2022
# 4     New York City residency is generally required ...  07/03/2023_2022
# ...                                                 ...              ...
# 6239  New York City Residency is not required for th...  06/23/2023_2022
# 6240  New York City Residency is not required for th...  06/21/2023_2022
# 6241  New York City residency is generally required ...  05/25/2023_2022
# 6242  New York City Residency is not required for th...  05/08/2023_2022
# 6243  New York City residency is generally required ...  02/23/2023_2022
#
#             Post Until  Posting Updated     Process Date
# 0     07-NOV-2023_2022  04/17/2023_2022  07/11/2023_2022
# 1     20-SEP-2023_2022  06/22/2023_2022  07/11/2023_2022
# 2     02-NOV-2023_2022  07/05/2023_2022  07/11/2023_2022
# 3     11-AUG-2023_2022  06/21/2023_2022  07/11/2023_2022
# 4     02-AUG-2023_2022  07/06/2023_2022  07/11/2023_2022
# ...                ...              ...              ...
# 6239  30-JUL-2023_2022  06/23/2023_2022  07/11/2023_2022
# 6240  17-JUL-2023_2022  06/21/2023_2022  07/11/2023_2022
# 6241  21-NOV-2023_2022  05/30/2023_2022  07/11/2023_2022
# 6242          nan_2022  05/08/2023_2022  07/11/2023_2022
# 6243  22-AUG-2023_2022  02/23/2023_2022  07/11/2023_2022
#
# [6244 rows x 30 columns]

# %%
#map
s = pd.Series(["cat","dog","NaN","rabbit"])
s
# Out:
# 0       cat
# 1       dog
# 2       NaN
# 3    rabbit
# dtype: object

# %%
s.map({"cat":"kitten", "dog":"puppy"})
# Out:
# 0    kitten
# 1     puppy
# 2       NaN
# 3       NaN
# dtype: object

# %%
def change_word(title):
    return title.replace("DEPT","kitten")

data["Agency"].map(change_word)
# Out:
# 0       kitten OF HEALTH/MENTAL HYGIENE
# 1          DEPARTMENT OF BUSINESS SERV.
# 2       kitten OF HEALTH/MENTAL HYGIENE
# 3        CONSUMER AND WORKER PROTECTION
# 4                     POLICE DEPARTMENT
#                      ...
# 6239     CONSUMER AND WORKER PROTECTION
# 6240            DEPARTMENT OF BUILDINGS
# 6241           DEPARTMENT FOR THE AGING
# 6242       DEPARTMENT OF TRANSPORTATION
# 6243           DEPARTMENT FOR THE AGING
# Name: Agency, Length: 6244, dtype: object

# %%
data["Agency"].map("this position is offered by {}".format)
# Out:
# 0       this position is offered by DEPT OF HEALTH/MEN...
# 1       this position is offered by DEPARTMENT OF BUSI...
# 2       this position is offered by DEPT OF HEALTH/MEN...
# 3       this position is offered by CONSUMER AND WORKE...
# 4           this position is offered by POLICE DEPARTMENT
#                               ...
# 6239    this position is offered by CONSUMER AND WORKE...
# 6240    this position is offered by DEPARTMENT OF BUIL...
# 6241    this position is offered by DEPARTMENT FOR THE...
# 6242    this position is offered by DEPARTMENT OF TRAN...
# 6243    this position is offered by DEPARTMENT FOR THE...
# Name: Agency, Length: 6244, dtype: object

# %%
#"cas des naN mal gérés"
s.map(function na_action="ignore")
s.apply(function na_action="ignore")
s.applymap(function na_action="ignore")
