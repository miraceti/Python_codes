# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#df0 = pd.read_csv("data20230518.csv")
df0 = pd.read_csv("/mnt/1c204b66-1229-4080-9d78-8566b7957960/outil/python/Python_codes/pandas/data20230518.csv")
df0
# Out:
# /tmp/ipykernel_15306/2426207081.py:3: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("/mnt/1c204b66-1229-4080-9d78-8566b7957960/outil/python/Python_codes/pandas/data20230518.csv")
#        rowid    pl_name hostname pl_letter    hd_name   hip_name  \
# 0          1   11 Com b   11 Com         b  HD 107383  HIP 60202
# 1          2   11 Com b   11 Com         b  HD 107383  HIP 60202
# 2          3   11 UMi b   11 UMi         b  HD 136726  HIP 74793
# 3          4   11 UMi b   11 UMi         b  HD 136726  HIP 74793
# 4          5   11 UMi b   11 UMi         b  HD 136726  HIP 74793
# ...      ...        ...      ...       ...        ...        ...
# 34731  34732  ups And d  ups And         d    HD 9826   HIP 7513
# 34732  34733  ups And d  ups And         d    HD 9826   HIP 7513
# 34733  34734  ups Leo b  ups Leo         b        NaN        NaN
# 34734  34735   xi Aql b   xi Aql         b  HD 188310  HIP 97938
# ...

# %%
#changer nombre decimale pour les nombre float   avec 2 decimales "
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df0.info()
df0.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34736 entries, 0 to 34735
# Columns: 121 entries, rowid to pl_ntranspec
# dtypes: float64(69), int64(25), object(27)
# memory usage: 32.1+ MB
#          rowid  default_flag  sy_snum  sy_pnum  sy_mnum  cb_flag  disc_year  \
# count 34736.00      34736.00 34736.00 34736.00 34736.00 34736.00   34736.00
# mean  17368.50          0.16     1.08     1.88     0.00     0.00    2015.25
# std   10027.56          0.36     0.30     1.20     0.00     0.05       3.72
# min       1.00          0.00     1.00     1.00     0.00     0.00    1992.00
# 25%    8684.75          0.00     1.00     1.00     0.00     0.00    2014.00
# 50%   17368.50          0.00     1.00     1.00     0.00     0.00    2016.00
# 75%   26052.25          0.00     1.00     2.00     0.00     0.00    2016.00
# max   34736.00          1.00     4.00     8.00     0.00     1.00    2023.00
#
#        rv_flag  pul_flag  ptv_flag  ...  sy_gaiamag  sy_icmag  sy_tmag  \
# ...

# %%
#nombre de valeur nulle
df0.isnull().sum()
# Out:
# rowid               0
# pl_name             0
# hostname            0
# pl_letter           0
# hd_name         32384
#                 ...
# st_nphot            0
# st_nrvc             0
# st_nspec            0
# pl_nespec           0
# pl_ntranspec        0
# Length: 121, dtype: int64

# %%
#nombre de ligne unique
df0.nunique()
# Out:
# rowid           34736
# pl_name          5419
# hostname         4037
# pl_letter           8
# hd_name           680
#                 ...
# st_nphot           35
# st_nrvc            13
# st_nspec           12
# pl_nespec          19
# pl_ntranspec       55
# Length: 121, dtype: int64

# %%
df0.sort_values(by="sy_pnum").head()
# Out:
#        rowid        pl_name     hostname pl_letter    hd_name   hip_name  \
# 0          1       11 Com b       11 Com         b  HD 107383  HIP 60202
# 17208  17209  Kepler-1943 b  Kepler-1943         b        NaN        NaN
# 17207  17208  Kepler-1943 b  Kepler-1943         b        NaN        NaN
# 17206  17207  Kepler-1943 b  Kepler-1943         b        NaN        NaN
# 17205  17206  Kepler-1943 b  Kepler-1943         b        NaN        NaN
#
#               tic_id                       gaia_id  default_flag  sy_snum  \
# 0       TIC 72437047  Gaia DR2 3946945413106333696             1        2
# 17208  TIC 138100223  Gaia DR2 2077381299180152704             0        1
# 17207  TIC 138100223  Gaia DR2 2077381299180152704             0        1
# 17206  TIC 138100223  Gaia DR2 2077381299180152704             0        1
# 17205  TIC 138100223  Gaia DR2 2077381299180152704             1        1
#
#        ...  sy_kepmag   rowupdate        pl_pubdate releasedate  pl_nnotes  \
# ...

# %%
df0.sort_values(by="sy_pnum", ascending=False).head()
# Out:
#       rowid    pl_name hostname pl_letter hd_name hip_name         tic_id  \
# 5620   5621  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5649   5650  KOI-351 h  KOI-351         h     NaN      NaN  TIC 267667295
# 5619   5620  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5621   5622  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5622   5623  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
#
#                            gaia_id  default_flag  sy_snum  ...  sy_kepmag  \
# 5620  Gaia DR2 2132193431285570304             0        1  ...      13.80
# 5649  Gaia DR2 2132193431285570304             0        1  ...      13.80
# 5619  Gaia DR2 2132193431285570304             0        1  ...      13.80
# 5621  Gaia DR2 2132193431285570304             0        1  ...      13.80
# 5622  Gaia DR2 2132193431285570304             0        1  ...      13.80
#
# ...

# %%
df0.sort_values(by="sy_pnum", ascending=False).head(20)
# Out:
#       rowid    pl_name hostname pl_letter hd_name hip_name         tic_id  \
# 5620   5621  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5649   5650  KOI-351 h  KOI-351         h     NaN      NaN  TIC 267667295
# 5619   5620  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5621   5622  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5622   5623  KOI-351 e  KOI-351         e     NaN      NaN  TIC 267667295
# 5623   5624  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# 5624   5625  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# 5625   5626  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# 5626   5627  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# 5627   5628  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# 5628   5629  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# 5629   5630  KOI-351 f  KOI-351         f     NaN      NaN  TIC 267667295
# ...
