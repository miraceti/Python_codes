# %%
import pandas as pd

pd.set_option('display.max_columns', None)#all the columns
#pd.set_option('display.max_rows', None)#all the rows comment if to many

# %%
#######   astuces / tips  #####
import pandas as pd
import numpy as np
data = pd.read_csv('anime.csv')
data.head()
# Out:
#    Anime-PlanetID                                           Name  \
# 0              10                           The Prince of Tennis
# 1             100                        Neon Genesis Evangelion
# 2            1000              Full Metal Panic! The Second Raid
# 3           10000                 22/7: Shampoo no Nioi ga Shita
# 4           10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
#
#        Alternative Name Rating Score Number Votes  \
# 0   Tennis no Ouji-sama        4.037        10889
# 1  Shinseiki Evangelion        4.248        54463
# 2               Unknown         4.35        23948
# 3               Unknown          2.8          131
# 4               Unknown        1.271           21
#
#                                                 Tags  \
# 0  Comedy, Drama, Shounen, Sports, Tennis, Based ...
# 1  Drama, Mecha, Sci Fi, Conspiracy, Kaijuu, Lone...
# 2  Action, Comedy, Mecha, Sci Fi, Shounen, Milita...
# ...

# %%
#replace the NaN values
data.fillna('rien')

# %%
#rzeplace value in the dataframe
data = data.fillna('rien')

# %%
#replace
data.replace('Unknown','Inconnu', inplace=True) 
#si pas de inpace il faut faire une affectation pour modfier le dataframe

# %%
data
# Out:
#        Anime-PlanetID                                           Name  \
# 0                  10                           The Prince of Tennis
# 1                 100                        Neon Genesis Evangelion
# 2                1000              Full Metal Panic! The Second Raid
# 3               10000                 22/7: Shampoo no Nioi ga Shita
# 4               10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
# ...               ...                                            ...
# 16616            9995                   Kitsunetsuki: Kedamonodamono
# 16617            9996                Irodorimidori: Outsider Requiem
# 16618            9997                                     Kura Sushi
# 16619            9998                        High School Fleet Movie
# 16620            9999  Drive Agent Personal: Shiawase wo Mamoru Mono
#
#            Alternative Name Rating Score Number Votes  \
# 0       Tennis no Ouji-sama        4.037        10889
# ...

# %%
#change on a condition with loc  or at
data.loc[data['Type']=='Web', 'Type'] = 0

# %%
data
#modify without inplace parameter
# Out:
#        Anime-PlanetID                                           Name  \
# 0                  10                           The Prince of Tennis
# 1                 100                        Neon Genesis Evangelion
# 2                1000              Full Metal Panic! The Second Raid
# 3               10000                 22/7: Shampoo no Nioi ga Shita
# 4               10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
# ...               ...                                            ...
# 16616            9995                   Kitsunetsuki: Kedamonodamono
# 16617            9996                Irodorimidori: Outsider Requiem
# 16618            9997                                     Kura Sushi
# 16619            9998                        High School Fleet Movie
# 16620            9999  Drive Agent Personal: Shiawase wo Mamoru Mono
#
#            Alternative Name Rating Score Number Votes  \
# 0       Tennis no Ouji-sama        4.037        10889
# ...

# %%
data.loc[data['Type']==0, 'Type'] = 'Web'

# %%
data
# Out:
#        Anime-PlanetID                                           Name  \
# 0                  10                           The Prince of Tennis
# 1                 100                        Neon Genesis Evangelion
# 2                1000              Full Metal Panic! The Second Raid
# 3               10000                 22/7: Shampoo no Nioi ga Shita
# 4               10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
# ...               ...                                            ...
# 16616            9995                   Kitsunetsuki: Kedamonodamono
# 16617            9996                Irodorimidori: Outsider Requiem
# 16618            9997                                     Kura Sushi
# 16619            9998                        High School Fleet Movie
# 16620            9999  Drive Agent Personal: Shiawase wo Mamoru Mono
#
#            Alternative Name Rating Score Number Votes  \
# 0       Tennis no Ouji-sama        4.037        10889
# ...

# %%
#change one value by position
data.loc[2,'Type']= 'FMP TSR'

# %%
data
# Out:
#        Anime-PlanetID                                           Name  \
# 0                  10                           The Prince of Tennis
# 1                 100                        Neon Genesis Evangelion
# 2                1000              Full Metal Panic! The Second Raid
# 3               10000                 22/7: Shampoo no Nioi ga Shita
# 4               10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
# ...               ...                                            ...
# 16616            9995                   Kitsunetsuki: Kedamonodamono
# 16617            9996                Irodorimidori: Outsider Requiem
# 16618            9997                                     Kura Sushi
# 16619            9998                        High School Fleet Movie
# 16620            9999  Drive Agent Personal: Shiawase wo Mamoru Mono
#
#            Alternative Name Rating Score Number Votes  \
# 0       Tennis no Ouji-sama        4.037        10889
# ...

# %%
#use the numpy function "where"
np.where(data['Name']== 'Full Metal panic! The Second Raid',True, False)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
data['FMP TSR'] = np.where(data['Name']== 'Full Metal panic! The Second Raid',True, False)

# %%
data
# Out:
#        Anime-PlanetID                                           Name  \
# 0                  10                           The Prince of Tennis
# 1                 100                        Neon Genesis Evangelion
# 2                1000              Full Metal Panic! The Second Raid
# 3               10000                 22/7: Shampoo no Nioi ga Shita
# 4               10001  Oshiri Tantei: Puputto Fumutto Kaiketsu Dance
# ...               ...                                            ...
# 16616            9995                   Kitsunetsuki: Kedamonodamono
# 16617            9996                Irodorimidori: Outsider Requiem
# 16618            9997                                     Kura Sushi
# 16619            9998                        High School Fleet Movie
# 16620            9999  Drive Agent Personal: Shiawase wo Mamoru Mono
#
#            Alternative Name Rating Score Number Votes  \
# 0       Tennis no Ouji-sama        4.037        10889
# ...

# %%
#use mask
data['Duration'].mask(data['EndYear']=='2005',0 )
# Out:
# 0              0
# 1        Inconnu
# 2              0
# 3              5
# 4              2
#           ...
# 16616          4
# 16617          2
# 16618          4
# 16619        103
# 16620          2
# Name: Duration, Length: 16621, dtype: object

# %%
#update a df from another df
df = pd.DataFrame({'A':[1,2,3], 'B':[400, 500, 600]})
new_df = pd.DataFrame({'B':[4,5,6], 'C':[7, 8, 9]})

# %%
df
# Out:
#    A    B
# 0  1  400
# 1  2  500
# 2  3  600

# %%
new_df
# Out:
#    B  C
# 0  4  7
# 1  5  8
# 2  6  9

# %%
df.update(new_df)

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam','curb_loc', 'status',
'health', 'spc_latin',  'steward','sidewalk',  'problems', 
'root_stone', 'root_grate', 'root_other', 
'trunk_wire','trnk_light', 'trnk_other', 
'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
#check for null values
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
#what are the null values
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
#histogram
tree_census_subset.hist(bins=60, figsize = (20, 10))
# Out:
# array([[<AxesSubplot: title={'center': 'tree_id'}>,
#         <AxesSubplot: title={'center': 'tree_dbh'}>],
#        [<AxesSubplot: title={'center': 'stump_diam'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
tree_census_subset[tree_census_subset['tree_dbh'] > 300]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 180962   370606       389           0          OnCurb  Alive   Fair
# 201195   418433       318           0          OnCurb  Alive   Good
# 228048   433258       450           0  OffsetFromCurb   Dead    NaN
# 270493   476317       318           0          OnCurb  Alive   Good
#
#                       spc_latin steward  sidewalk      problems root_stone  \
# 2405            Quercus bicolor    1or2    Damage          None         No
# 180962  Liriodendron tulipifera    None    Damage          None         No
# 201195    Platanus x acerifolia    None  NoDamage  BranchLights         No
# 228048                      NaN     NaN       NaN           NaN         No
# 270493        Quercus palustris    None  NoDamage          None         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# ...

# %%
tree_census_subset[tree_census_subset['stump_diam'] > 100]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 11342    206819         0         140   OnCurb  Stump    NaN       NaN
# 67831    253992         0         118   OnCurb  Stump    NaN       NaN
# 73377    278733         0         109   OnCurb  Stump    NaN       NaN
# 89539    286364         0         134   OnCurb  Stump    NaN       NaN
# 137315   319640         0         131   OnCurb  Stump    NaN       NaN
# 267239   484857         0         115   OnCurb  Stump    NaN       NaN
# 399840   624806         0         107   OnCurb  Stump    NaN       NaN
# 420332   638508         0         104   OnCurb  Stump    NaN       NaN
# 497829   711302         0         125   OnCurb  Stump    NaN       NaN
# 543264    35364         0         120   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 11342      NaN      NaN      NaN         No         No         No         No
# ...

# %%
tree_census_subset[tree_census_subset['tree_dbh'] > 50]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk      problems  \
# ...

# %%
big_trees = tree_census_subset[tree_census_subset['tree_dbh'] > 50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 2405     168583       425           0          OnCurb  Alive            Good
# 3738     199546        51           0          OnCurb  Alive            Good
# 4887     139665        72           0  OffsetFromCurb  Alive            Good
# 6724     209349       122           0          OnCurb  Alive            Good
# 10083    215075       169           0          OnCurb  Alive            Good
# ...         ...       ...         ...             ...    ...             ...
# 675265   179496        52           0  OffsetFromCurb  Alive            Good
# 677954   166796        54           0          OnCurb  Alive            Good
# 679894   169501        51           0          OnCurb  Alive            Good
# 681736   179366       281           0          OnCurb  Alive            Fair
# 682788   183910       127           0          OnCurb   Dead  Not Applicable
#
# ...

# %%
big_trees[['tree_id','tree_dbh']].plot()
# Out:
# <AxesSubplot: >

# %%
big_trees[['tree_id','tree_dbh']].plot(kind='scatter', x='tree_id', y='tree_dbh')
# Out:
# <AxesSubplot: xlabel='tree_id', ylabel='tree_dbh'>

# %%
big_stumps = tree_census_subset[tree_census_subset['stump_diam'] > 100]
big_stumps
big_stumps[['tree_id','stump_diam']].plot(kind='scatter', x='tree_id', y='stump_diam')
# Out:
# <AxesSubplot: xlabel='tree_id', ylabel='stump_diam'>

# %%
big_trees[['tree_id','tree_dbh']].plot(kind='scatter', 
                                       x='tree_id', y='tree_dbh',
                                       figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='tree_id', ylabel='tree_dbh'>

# %%
big_stumps = tree_census_subset[tree_census_subset['stump_diam'] > 50]
big_stumps[['tree_id','stump_diam']].plot(kind='scatter', 
                                         x='tree_id', 
                                         y='stump_diam', figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='tree_id', ylabel='stump_diam'>

# %%
big_stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6122     200925         0          52   OnCurb  Stump    NaN       NaN
# 6177     200924         0          55   OnCurb  Stump    NaN       NaN
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9872     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 645994   135904         0          65   OnCurb  Stump    NaN       NaN
# 646336   151125         0          55   OnCurb  Stump    NaN       NaN
# 649174   154188         0          65   OnCurb  Stump    NaN       NaN
# 652690   154181         0          60   OnCurb  Stump    NaN       NaN
# 653066   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
#convert count into a dataframe
pd.DataFrame(tree_census_subset['spc_latin'].value_counts())
# Out:
#                                     spc_latin
# Platanus x acerifolia                   87014
# Gleditsia triacanthos var. inermis      64264
# Pyrus calleryana                        58931
# Quercus palustris                       53185
# Acer platanoides                        34189
# ...                                       ...
# Pinus nigra                                37
# Pinus rigida                               33
# Maclura pomifera                           29
# Pinus sylvestris                           25
# Pinus virginiana                           10
#
# [132 rows x 1 columns]

# %%
#plot it
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_census_subset['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
tree_census_subset['problems'].value_counts()
# Out:
# None                                                                          426280
# Stones                                                                         95673
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
# RootOther                                                                      11418
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther               1
# MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther                         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 232, dtype: int64

# %%
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
stumps = tree_census_subset[tree_census_subset['status']=='Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
deads = tree_census_subset[tree_census_subset['status']=='Dead']
deads
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %%
tree_census_subset.columns
# Out:
# Index(['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
#        'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other'],
#       dtype='object')

# %%
tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_problems = tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %%
#clean data
stumps = tree_census_subset[tree_census_subset['status']=='Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
#remove stumps
#tree_census_subset =  tree_census_subset[tree_census_subset['status'] !='Stump']
#tree_census_subset =  tree_census_subset[tree_census_subset['status'] !='Dead']

# %%
tree_census_subset['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
#tree_census_subset.fillna('Not Applicable')#trop imprécis
mask = ((tree_census_subset['status'] =='Stump')| (tree_census_subset['status'] =='Dead'))

# %%
tree_census_subset.loc[mask, 
                       'health'] = tree_census_subset.loc[mask, 
                        'health'].fillna('Not Applicable')

# %%
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#        spc_latin steward sidewalk problems root_stone root_grate root_other  \
# ...

# %%
#all the nan columns in once
mask = ((tree_census_subset['status'] =='Stump')| (tree_census_subset['status'] =='Dead'))
tree_census_subset.loc[mask] = tree_census_subset.loc[mask].fillna('Not Applicable')
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  \
# ...

# %%
tree_census_subset.isna().sum()#il reste des valeurs manquantes ou NaN
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward sidewalk problems root_stone root_grate  \
# 32889  Fraxinus pennsylvanica    None   Damage     None         No         No
#
#       root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 32889         No         No         No         No         No        No
#
#       brch_other
# 32889         No

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None              487823
# 1or2              143557
# Not Applicable     31615
# 3or4               19183
# 4orMore             1610
# Name: steward, dtype: int64

# %%
tree_census_subset[tree_census_subset['sidewalk'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 346299   540677         7           0  OffsetFromCurb  Alive   Good
#
#                                  spc_latin steward sidewalk problems  \
# 346299  Gleditsia triacanthos var. inermis    None      NaN     None
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 346299         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 346299         No        No         No

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage          464978
# Damage            187194
# Not Applicable     31615
# Name: sidewalk, dtype: int64

# %%
tree_census_subset[tree_census_subset['spc_latin'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 356613   562532         4           0   OnCurb  Alive   Good       NaN
# 427541   630814        11           0   OnCurb  Alive   Poor       NaN
# 431417   651014        40           0   OnCurb  Alive   Good       NaN
# 608632    47941         5           0   OnCurb  Alive   Good       NaN
# 656960   150745         3           0   OnCurb  Alive   Good       NaN
#
#        steward  sidewalk problems root_stone root_grate root_other trunk_wire  \
# 356613    1or2  NoDamage   Stones        Yes         No         No         No
# 427541    None    Damage      NaN         No         No         No         No
# 431417    None    Damage   Stones        Yes         No         No         No
# 608632    1or2  NoDamage     None         No         No         No         No
# 656960    1or2    Damage     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# ...

# %%
tree_census_subset[tree_census_subset['problems'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 120289   332668        30           0  OffsetFromCurb  Alive   Fair
# 121488   332669        28           0  OffsetFromCurb  Alive   Fair
# 121685   332670        24           0  OffsetFromCurb  Alive   Fair
# 133470   332693        11           0  OffsetFromCurb  Alive   Good
# 133812   332692        15           0  OffsetFromCurb  Alive   Good
# 134820   332694        28           0  OffsetFromCurb  Alive   Good
# 144137   332947         3           0          OnCurb  Alive   Good
# 145324   332543         9           0          OnCurb  Alive   Good
# 145337   332541         8           0          OnCurb  Alive   Good
# 146314   332542         8           0          OnCurb  Alive   Good
# 146378   332950         3           0          OnCurb  Alive   Good
# 146430   332949         3           0          OnCurb  Alive   Good
# 146630   332948         3           0          OnCurb  Alive   Good
# ...

# %%
tree_census_subset['problems'].value_counts()
# Out:
# None                                                                          426280
# Stones                                                                         95673
# Not Applicable                                                                 31615
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,RootOther,TrunkLights,BranchLights                                     1
# WiresRope,TrunkOther,BranchLights,Sneakers                                         1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 233, dtype: int64

# %%
tree_census_subset['problems'].fillna('None', inplace=True)
tree_census_subset['health'].fillna('Good', inplace=True)
tree_census_subset['spc_latin'].fillna('No Observation', inplace=True)
tree_census_subset['sidewalk'].fillna('NoDamage', inplace=True)
# Out:
# /tmp/ipykernel_13230/2480927170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['problems'].fillna('None', inplace=True)
# /tmp/ipykernel_13230/2480927170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['health'].fillna('Good', inplace=True)
# /tmp/ipykernel_13230/2480927170.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
tree_census_subset.isna().sum()#il reste des valeurs manquantes ou NaN  ? ou pas !
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
#no more missing values!!!!

# %%
big_trees3 = tree_census_subset[(tree_census_subset['tree_dbh'] > 60)|(tree_census_subset['stump_diam'] > 50)]
big_trees3
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 2405     168583       425           0          OnCurb  Alive            Good
# 4887     139665        72           0  OffsetFromCurb  Alive            Good
# 6122     200925         0          52          OnCurb  Stump  Not Applicable
# 6177     200924         0          55          OnCurb  Stump  Not Applicable
# 6466     166008         0          72          OnCurb  Stump  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 667425   151958        66           0  OffsetFromCurb  Alive            Fair
# 673105   165324        79           0          OnCurb  Alive            Good
# 674016   184879       105           0          OnCurb  Alive            Fair
# 681736   179366       281           0          OnCurb  Alive            Fair
# 682788   183910       127           0          OnCurb   Dead  Not Applicable
#
# ...

# %%
tree_census_subset2 = tree_census_subset[(tree_census_subset['tree_dbh'] <= 60)&(tree_census_subset['stump_diam'] <= 60)]
tree_census_subset2
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset_alive = tree_census_subset[tree_census_subset['status']=='Alive']
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset_dead_or_stump = tree_census_subset[(tree_census_subset['status']=='Dead')|(tree_census_subset['status']=='Stump')]
tree_census_subset_dead_or_stump
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 37       211205         0          16          OnCurb  Stump  Not Applicable
# 57       187807         0           0          OnCurb   Dead  Not Applicable
# 196      208322        10           0          OnCurb   Dead  Not Applicable
# 209      209058         6           0          OnCurb   Dead  Not Applicable
# 239      203597         0          15          OnCurb  Stump  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 683693   156162         3           0  OffsetFromCurb   Dead  Not Applicable
# 683695   170888         0           5          OnCurb  Stump  Not Applicable
# 683697   177922         0          17          OnCurb  Stump  Not Applicable
# 683698   193791         3           0          OnCurb   Dead  Not Applicable
# 683699   172660         0           4          OnCurb  Stump  Not Applicable
#
# ...

# %%
#group by tree type
tree_census_subset_alive.groupby('spc_latin').mean()
# Out:
# /tmp/ipykernel_13230/1622721010.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tree_census_subset_alive.groupby('spc_latin').mean()
#                          tree_id   tree_dbh  stump_diam
# spc_latin
# Acer               473760.032486  11.675424         0.0
# Acer buergerianum  395036.818182   8.090909         0.0
# Acer campestre     383840.281176   7.126275         0.0
# Acer ginnala       370801.015129   7.869204         0.0
# Acer griseum       347632.222727   3.509091         0.0
# ...                          ...        ...         ...
# Tsuga canadensis   268551.181818   5.193182         0.0
# Ulmus americana    308680.330533  11.953229         0.0
# Ulmus parvifolia   303458.441347   7.417587         0.0
# Ulmus pumila       318869.944828  11.475862         0.0
# ...

# %%
tree_census_subset_alive.groupby('spc_latin').describe()
# Out:
#                    tree_id                                                    \
#                      count           mean            std      min        25%
# spc_latin
# Acer                7080.0  473760.032486  164789.472498    373.0  401640.00
# Acer buergerianum    110.0  395036.818182  179390.324434  60373.0  276777.50
# Acer campestre      2550.0  383840.281176  184855.325418    214.0  265393.25
# Acer ginnala        2049.0  370801.015129  184408.353698   1789.0  244993.00
# Acer griseum         220.0  347632.222727  181391.826314   8643.0  178650.75
# ...                    ...            ...            ...      ...        ...
# Tsuga canadensis      88.0  268551.181818  180119.744951  16887.0  145061.75
# Ulmus americana     7975.0  308680.330533  206913.335265    123.0  120745.50
# Ulmus parvifolia    5345.0  303458.441347  188585.417734    113.0  145469.00
# Ulmus pumila        1595.0  318869.944828  203420.294281    305.0  130366.50
# ...

# %%
tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe()
# Out:
#                      count       mean       std  min  25%   50%   75%    max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0   59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0   28.0
# Acer campestre      2550.0   7.126275  4.437674  0.0  4.0   6.0   9.0   64.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0   40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0   30.0
# ...                    ...        ...       ...  ...  ...   ...   ...    ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0   21.0
# Ulmus americana     7975.0  11.953229  9.426278  0.0  4.0   9.0  17.0   65.0
# Ulmus parvifolia    5345.0   7.417587  5.867390  0.0  3.0   5.0  10.0  118.0
# Ulmus pumila        1595.0  11.475862  9.903164  1.0  4.0   9.0  17.0  149.0
# Zelkova serrata    29258.0   7.863559  5.297524  0.0  4.0   6.0  11.0  210.0
#
# [133 rows x 8 columns]

# %%
tree_census_subset_alive[tree_census_subset_alive['tree_dbh']==0]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 5312      38793         0           0          OnCurb  Alive   Good
# 30524    204988         0           0          OnCurb  Alive   Good
# 44772    241329         0           0  OffsetFromCurb  Alive   Good
# 47154    173248         0           0          OnCurb  Alive   Good
# 47484    204173         0           0          OnCurb  Alive   Poor
# ...         ...       ...         ...             ...    ...    ...
# 658977   162280         0           0          OnCurb  Alive   Poor
# 671073    17796         0           0          OnCurb  Alive   Fair
# 671971   120612         0           0          OnCurb  Alive   Good
# 672443   116239         0           0          OnCurb  Alive   Good
# 680530    51015         0           0          OnCurb  Alive   Good
#
#                    spc_latin steward  sidewalk problems root_stone root_grate  \
# ...

# %%
#on filtre uniquement les valeur entre 25%  et 75% et on exclue les autres

# %%
stats = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe()
stats
# Out:
#                      count       mean       std  min  25%   50%   75%    max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0   59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0   28.0
# Acer campestre      2550.0   7.126275  4.437674  0.0  4.0   6.0   9.0   64.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0   40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0   30.0
# ...                    ...        ...       ...  ...  ...   ...   ...    ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0   21.0
# Ulmus americana     7975.0  11.953229  9.426278  0.0  4.0   9.0  17.0   65.0
# Ulmus parvifolia    5345.0   7.417587  5.867390  0.0  3.0   5.0  10.0  118.0
# Ulmus pumila        1595.0  11.475862  9.903164  1.0  4.0   9.0  17.0  149.0
# Zelkova serrata    29258.0   7.863559  5.297524  0.0  4.0   6.0  11.0  210.0
#
# [133 rows x 8 columns]

# %%
stats = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()
stats
# Out:
#              spc_latin    count       mean       std  min  25%   50%   75%  \
# 0                 Acer   7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0
# 1    Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0
# 2       Acer campestre   2550.0   7.126275  4.437674  0.0  4.0   6.0   9.0
# 3         Acer ginnala   2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0
# 4         Acer griseum    220.0   3.509091  3.578846  1.0  2.0   2.0   3.0
# ..                 ...      ...        ...       ...  ...  ...   ...   ...
# 128   Tsuga canadensis     88.0   5.193182  3.959153  0.0  2.0   3.5   7.0
# 129    Ulmus americana   7975.0  11.953229  9.426278  0.0  4.0   9.0  17.0
# 130   Ulmus parvifolia   5345.0   7.417587  5.867390  0.0  3.0   5.0  10.0
# 131       Ulmus pumila   1595.0  11.475862  9.903164  1.0  4.0   9.0  17.0
# 132    Zelkova serrata  29258.0   7.863559  5.297524  0.0  4.0   6.0  11.0
#
#        max
# 0     59.0
# 1     28.0
# 2     64.0
# 3     40.0
# ...

# %%
stats_alive = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin','25%','75%']]
stats_alive
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128   Tsuga canadensis  2.0   7.0
# 129    Ulmus americana  4.0  17.0
# 130   Ulmus parvifolia  3.0  10.0
# 131       Ulmus pumila  4.0  17.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]

# %%
tree_census_subset_alive.merge(stats_alive, on='spc_latin', how='left')
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652168   155433        25           0   OnCurb  Alive   Good
# 652169   183795         7           0   OnCurb  Alive   Good
# 652170   166161        12           0   OnCurb  Alive   Good
# 652171   184028         9           0   OnCurb  Alive   Good
# 652172   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset_alive.columns
# Out:
# Index(['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
#        'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', '25%_x', '75%_x', '25%_y',
#        '75%_y'],
#       dtype='object')

# %%
tree_census_subset_alive=tree_census_subset_alive.merge(stats_alive, on='spc_latin', how='left')
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652168   155433        25           0   OnCurb  Alive   Good
# 652169   183795         7           0   OnCurb  Alive   Good
# 652170   166161        12           0   OnCurb  Alive   Good
# 652171   184028         9           0   OnCurb  Alive   Good
# 652172   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
mask = tree_census_subset_alive['tree_dbh'] < tree_census_subset_alive['25%']
tree_census_subset_alive.loc[mask,'tree_dbh'] = tree_census_subset_alive['25%']

mask = tree_census_subset_alive['tree_dbh'] > tree_census_subset_alive['75%']
tree_census_subset_alive.loc[mask,'tree_dbh'] = tree_census_subset_alive['75%']

tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652168   155433      24.0           0   OnCurb  Alive   Good
# 652169   183795       5.0           0   OnCurb  Alive   Good
# 652170   166161      12.0           0   OnCurb  Alive   Good
# 652171   184028       9.0           0   OnCurb  Alive   Good
# 652172   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
#pandas groupby
data1 = pd.read_csv('NYC_Jobs.csv')
data1
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 0     559432   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1     584642    DEPARTMENT OF BUSINESS SERV.     External               1
# 2     578078   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 3     590587  CONSUMER AND WORKER PROTECTION     External               1
# 4     572710               POLICE DEPARTMENT     Internal               1
# ...      ...                             ...          ...             ...
# 6239  590893  CONSUMER AND WORKER PROTECTION     External               1
# 6240  590545         DEPARTMENT OF BUILDINGS     Internal               1
# 6241  585054        DEPARTMENT FOR THE AGING     Internal               1
# 6242  582278    DEPARTMENT OF TRANSPORTATION     External               1
# 6243  575105        DEPARTMENT FOR THE AGING     Internal               1
#
#                                          Business Title  \
# ...

# %%
type(data1.groupby("Agency"))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
data1.groupby("Agency").mean()
# Out:
# /tmp/ipykernel_13230/252256748.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Agency").mean()
#                                       Job ID  # Of Positions  \
# Agency
# ADMIN FOR CHILDREN'S SVCS      563007.008000        5.856000
# ADMIN TRIALS AND HEARINGS      581808.144928        2.565217
# BOARD OF CORRECTION            591183.000000        2.000000
# BOROUGH PRESIDENT-BRONX        585509.875000        1.250000
# BOROUGH PRESIDENT-QUEENS       591260.000000        1.000000
# ...                                      ...             ...
# PUBLIC ADMINISTRATOR-NEW YORK  550243.500000        1.000000
# TAX COMMISSION                 590202.000000        2.000000
# TAXI & LIMOUSINE COMMISSION    571013.808696        1.556522
# ...

# %%
data1.groupby("Agency")['Salary Range From'].mean()
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS        69616.015360
# ADMIN TRIALS AND HEARINGS        59439.457391
# BOARD OF CORRECTION              55984.000000
# BOROUGH PRESIDENT-BRONX          47747.875000
# BOROUGH PRESIDENT-QUEENS         47270.000000
#                                      ...
# PUBLIC ADMINISTRATOR-NEW YORK    45850.000000
# TAX COMMISSION                       0.000000
# TAXI & LIMOUSINE COMMISSION      60444.987355
# TEACHERS RETIREMENT SYSTEM       67169.000000
# TECHNOLOGY & INNOVATION          63272.000000
# Name: Salary Range From, Length: 61, dtype: float64

# %%
data1.groupby("Agency")['Salary Range From'].agg(['mean','median'])
# Out:
#                                        mean   median
# Agency
# ADMIN FOR CHILDREN'S SVCS      69616.015360  71423.0
# ADMIN TRIALS AND HEARINGS      59439.457391  53797.0
# BOARD OF CORRECTION            55984.000000  55984.0
# BOROUGH PRESIDENT-BRONX        47747.875000  46216.5
# BOROUGH PRESIDENT-QUEENS       47270.000000  47270.0
# ...                                     ...      ...
# PUBLIC ADMINISTRATOR-NEW YORK  45850.000000  45850.0
# TAX COMMISSION                     0.000000      0.0
# TAXI & LIMOUSINE COMMISSION    60444.987355  62470.0
# TEACHERS RETIREMENT SYSTEM     67169.000000  67169.0
# TECHNOLOGY & INNOVATION        63272.000000  75000.0
#
# [61 rows x 2 columns]

# %%
def do_sth_to_the_group(grp):
    #print(grp)
    #print("**********")
    return grp.mean()
data1.groupby("Agency")['Salary Range From'].apply(do_sth_to_the_group)
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS        69616.015360
# ADMIN TRIALS AND HEARINGS        59439.457391
# BOARD OF CORRECTION              55984.000000
# BOROUGH PRESIDENT-BRONX          47747.875000
# BOROUGH PRESIDENT-QUEENS         47270.000000
#                                      ...
# PUBLIC ADMINISTRATOR-NEW YORK    45850.000000
# TAX COMMISSION                       0.000000
# TAXI & LIMOUSINE COMMISSION      60444.987355
# TEACHERS RETIREMENT SYSTEM       67169.000000
# TECHNOLOGY & INNOVATION          63272.000000
# Name: Salary Range From, Length: 61, dtype: float64

# %%
data1.groupby(["Agency","Posting Type"])['Salary Range From'].mean()
# Out:
# Agency                       Posting Type
# ADMIN FOR CHILDREN'S SVCS    External        69436.540328
#                              Internal        69787.077500
# ADMIN TRIALS AND HEARINGS    External        59357.684706
#                              Internal        59518.893714
# BOARD OF CORRECTION          External        55984.000000
#                                                  ...
# TAXI & LIMOUSINE COMMISSION  Internal        60335.047809
# TEACHERS RETIREMENT SYSTEM   External        67169.000000
#                              Internal        67169.000000
# TECHNOLOGY & INNOVATION      External        60302.916667
#                              Internal        65816.928571
# Name: Salary Range From, Length: 122, dtype: float64

# %%
pd.DataFrame(data1.groupby(["Agency","Posting Type"])['Salary Range From'].mean())
# Out:
#                                           Salary Range From
# Agency                      Posting Type
# ADMIN FOR CHILDREN'S SVCS   External           69436.540328
#                             Internal           69787.077500
# ADMIN TRIALS AND HEARINGS   External           59357.684706
#                             Internal           59518.893714
# BOARD OF CORRECTION         External           55984.000000
# ...                                                     ...
# TAXI & LIMOUSINE COMMISSION Internal           60335.047809
# TEACHERS RETIREMENT SYSTEM  External           67169.000000
#                             Internal           67169.000000
# TECHNOLOGY & INNOVATION     External           60302.916667
#                             Internal           65816.928571
#
# [122 rows x 1 columns]

# %%
pd.DataFrame(data1.groupby(["Agency","Posting Type"])[['Salary Range From','Salary Range To']].mean())
# Out:
#                                           Salary Range From  Salary Range To
# Agency                      Posting Type
# ADMIN FOR CHILDREN'S SVCS   External           69436.540328     95704.540328
#                             Internal           69787.077500     97247.577500
# ADMIN TRIALS AND HEARINGS   External           59357.684706     67796.802647
#                             Internal           59518.893714     67716.894000
# BOARD OF CORRECTION         External           55984.000000     64382.000000
# ...                                                     ...              ...
# TAXI & LIMOUSINE COMMISSION Internal           60335.047809     83013.877586
# TEACHERS RETIREMENT SYSTEM  External           67169.000000     85000.000000
#                             Internal           67169.000000     85000.000000
# TECHNOLOGY & INNOVATION     External           60302.916667     96449.983333
#                             Internal           65816.928571    100099.985714
#
# ...

# %%
pd.DataFrame(data1.groupby(["Agency","Posting Type"], as_index=False)[['Salary Range From','Salary Range To']].mean())
# Out:
#                           Agency Posting Type  Salary Range From  \
# 0      ADMIN FOR CHILDREN'S SVCS     External       69436.540328
# 1      ADMIN FOR CHILDREN'S SVCS     Internal       69787.077500
# 2      ADMIN TRIALS AND HEARINGS     External       59357.684706
# 3      ADMIN TRIALS AND HEARINGS     Internal       59518.893714
# 4            BOARD OF CORRECTION     External       55984.000000
# ..                           ...          ...                ...
# 117  TAXI & LIMOUSINE COMMISSION     Internal       60335.047809
# 118   TEACHERS RETIREMENT SYSTEM     External       67169.000000
# 119   TEACHERS RETIREMENT SYSTEM     Internal       67169.000000
# 120      TECHNOLOGY & INNOVATION     External       60302.916667
# 121      TECHNOLOGY & INNOVATION     Internal       65816.928571
#
#      Salary Range To
# 0       95704.540328
# 1       97247.577500
# 2       67796.802647
# 3       67716.894000
# 4       64382.000000
# ..               ...
# 117     83013.877586
# ...

# %%
data_groups = data1.groupby("Agency")

# %%
data1[data1['Agency']=="ADMIN FOR CHILDREN'S SVCS"]
# Out:
#       Job ID                     Agency Posting Type  # Of Positions  \
# 7     575579  ADMIN FOR CHILDREN'S SVCS     External               1
# 45    586822  ADMIN FOR CHILDREN'S SVCS     Internal               1
# 215   565722  ADMIN FOR CHILDREN'S SVCS     External               2
# 384   534116  ADMIN FOR CHILDREN'S SVCS     External               6
# 419   565722  ADMIN FOR CHILDREN'S SVCS     Internal               2
# ...      ...                        ...          ...             ...
# 5953  583006  ADMIN FOR CHILDREN'S SVCS     External               5
# 6029  481622  ADMIN FOR CHILDREN'S SVCS     Internal               1
# 6121  580553  ADMIN FOR CHILDREN'S SVCS     Internal               1
# 6169  542979  ADMIN FOR CHILDREN'S SVCS     External               1
# 6219  580739  ADMIN FOR CHILDREN'S SVCS     External               6
#
#                         Business Title             Civil Service Title  \
# ...

# %%
data_groups.first()
# Out:
#                                Job ID Posting Type  # Of Positions  \
# Agency
# ADMIN FOR CHILDREN'S SVCS      575579     External               1
# ADMIN TRIALS AND HEARINGS      582500     External               1
# BOARD OF CORRECTION            591183     Internal               2
# BOROUGH PRESIDENT-BRONX        580833     External               1
# BOROUGH PRESIDENT-QUEENS       591260     External               1
# ...                               ...          ...             ...
# PUBLIC ADMINISTRATOR-NEW YORK  574049     External               1
# TAX COMMISSION                 590202     Internal               2
# TAXI & LIMOUSINE COMMISSION    582590     External               1
# TEACHERS RETIREMENT SYSTEM     590318     Internal               1
# TECHNOLOGY & INNOVATION        547359     Internal               1
#
#                                                     Business Title  \
# Agency
# ADMIN FOR CHILDREN'S SVCS                             MDM Engineer
# ...

# %%
data_groups.groups
# Out:
# {'ADMIN FOR CHILDREN'S SVCS': [7, 45, 215, 384, 419, 481, 489, 521, 540, 552, 639, 702, 704, 745, 786, 795, 812, 978, 983, 1006, 1007, 1107, 1115, 1273, 1386, 1543, 1582, 1584, 1691, 1694, 1700, 1765, 1779, 1811, 1826, 1856, 1885, 2061, 2089, 2106, 2150, 2152, 2166, 2217, 2293, 2307, 2325, 2337, 2339, 2409, 2508, 2576, 2630, 2661, 2784, 2786, 2816, 2826, 2830, 2869, 2903, 2913, 2932, 2954, 3044, 3174, 3202, 3220, 3282, 3287, 3347, 3459, 3642, 3685, 3689, 3703, 3748, 3769, 3842, 3845, 3847, 3875, 3876, 3898, 3914, 3915, 3985, 4075, 4110, 4114, 4161, 4162, 4346, 4468, 4501, 4562, 4663, 4726, 4727, 4736, ...], 'ADMIN TRIALS AND HEARINGS': [36, 339, 410, 471, 502, 663, 803, 896, 939, 990, 1490, 1511, 1718, 1773, 1814, 1963, 2075, 2204, 2314, 2316, 2330, 2386, 2443, 2600, 2646, 2724, 2755, 2797, 2852, 2905, 2965, 3048, 3083, 3134, 3228, 3271, 3385, 3386, 3391, 3606, 3633, 3727, 3852, 3859, 3897, 3925, 4059, 4112, 4172, 4227, 4234, 4267, 4656, 4699, 4763, 4781, 4802, 4853, 4893, 5026, 5052
# ...

# %%
data_groups.groups.keys()
# Out:
# dict_keys(["ADMIN FOR CHILDREN'S SVCS", 'ADMIN TRIALS AND HEARINGS', 'BOARD OF CORRECTION', 'BOROUGH PRESIDENT-BRONX', 'BOROUGH PRESIDENT-QUEENS', 'BRONX COMMUNITY BOARD #6', 'BRONX DISTRICT ATTORNEY', 'BUSINESS INTEGRITY COMMISSION', 'CAMPAIGN FINANCE BOARD', 'CIVIL SERVICE COMMISSION', 'CIVILIAN COMPLAINT REVIEW BD', 'CONSUMER AND WORKER PROTECTION', 'CULTURAL AFFAIRS', 'DEPARTMENT FOR THE AGING', 'DEPARTMENT OF BUILDINGS', 'DEPARTMENT OF BUSINESS SERV.', 'DEPARTMENT OF CITY PLANNING', 'DEPARTMENT OF CORRECTION', 'DEPARTMENT OF FINANCE', 'DEPARTMENT OF INVESTIGATION', 'DEPARTMENT OF PROBATION', 'DEPARTMENT OF SANITATION', 'DEPARTMENT OF TRANSPORTATION', 'DEPT OF CITYWIDE ADMIN SVCS', 'DEPT OF DESIGN & CONSTRUCTION', 'DEPT OF ENVIRONMENT PROTECTION', 'DEPT OF HEALTH/MENTAL HYGIENE', 'DEPT OF PARKS & RECREATION', 'DEPT OF RECORDS & INFO SERVICE', 'DEPT OF YOUTH & COMM DEV SRVS', 'DEPT. OF HOMELESS SERVICES', 'DISTRICT ATTORNEY KINGS COUNTY', 'DISTRICT ATTORNEY RICHMOND COU', 'FINANCI
# ...

# %%
data_groups.get_group('HUMAN RIGHTS COMMISSION')
# Out:
#       Job ID                   Agency Posting Type  # Of Positions  \
# 443   589033  HUMAN RIGHTS COMMISSION     External               6
# 743   589033  HUMAN RIGHTS COMMISSION     Internal               6
# 781   589036  HUMAN RIGHTS COMMISSION     Internal               1
# 828   572487  HUMAN RIGHTS COMMISSION     Internal               1
# 860   577641  HUMAN RIGHTS COMMISSION     External               2
# 1029  581006  HUMAN RIGHTS COMMISSION     Internal               1
# 1162  574589  HUMAN RIGHTS COMMISSION     Internal               1
# 1265  575059  HUMAN RIGHTS COMMISSION     External               2
# 1337  589959  HUMAN RIGHTS COMMISSION     External               1
# 1442  574589  HUMAN RIGHTS COMMISSION     External               1
# 1449  579029  HUMAN RIGHTS COMMISSION     External               1
# 1995  583544  HUMAN RIGHTS COMMISSION     Internal               1
# 2064  574604  HUMAN RIGHTS COMMISSION     Internal               1
# ...

# %%
data_groups.groups.values()
# Out:
# dict_values([Int64Index([   7,   45,  215,  384,  419,  481,  489,  521,  540,  552,
#             ...
#             5585, 5665, 5761, 5804, 5828, 5953, 6029, 6121, 6169, 6219],
#            dtype='int64', length=125), Int64Index([  36,  339,  410,  471,  502,  663,  803,  896,  939,  990, 1490,
#             1511, 1718, 1773, 1814, 1963, 2075, 2204, 2314, 2316, 2330, 2386,
#             2443, 2600, 2646, 2724, 2755, 2797, 2852, 2905, 2965, 3048, 3083,
#             3134, 3228, 3271, 3385, 3386, 3391, 3606, 3633, 3727, 3852, 3859,
#             3897, 3925, 4059, 4112, 4172, 4227, 4234, 4267, 4656, 4699, 4763,
#             4781, 4802, 4853, 4893, 5026, 5052, 5338, 5407, 5444, 5453, 5465,
#             5679, 5973, 6093],
#            dtype='int64'), Int64Index([2566, 5127], dtype='int64'), Int64Index([ 753, 1423, 2059, 2542, 2794, 2990, 3227, 3297, 3442, 3813, 4650,
#             4715, 5254, 5702, 6092, 6188],
# ...

# %%
df = pd.DataFrame(
    {
        "Publish date" :[
            pd.Timestamp("2000-01-02"),
            pd.Timestamp("2000-01-02"),
            pd.Timestamp("2000-01-09"),
            pd.Timestamp("2000-01-16")
        ],
        "ID": [0, 1, 2, 3],
        "Price" :[10, 20, 30, 40]
    }
)

# %%
df
# Out:
#   Publish date  ID  Price
# 0   2000-01-02   0     10
# 1   2000-01-02   1     20
# 2   2000-01-09   2     30
# 3   2000-01-16   3     40

# %%
df.groupby("Publish date")['Price'].mean()
# Out:
# Publish date
# 2000-01-02    15.0
# 2000-01-09    30.0
# 2000-01-16    40.0
# Name: Price, dtype: float64

# %%
df.groupby(pd.Grouper(key="Publish date", freq="2W"))['Price'].mean()
# Out:
# Publish date
# 2000-01-02    15.0
# 2000-01-16    35.0
# Freq: 2W-SUN, Name: Price, dtype: float64

# %%
df.groupby(pd.Grouper(key="Publish date", freq="1D"))['Price'].mean()
# Out:
# Publish date
# 2000-01-02    15.0
# 2000-01-03     NaN
# 2000-01-04     NaN
# 2000-01-05     NaN
# 2000-01-06     NaN
# 2000-01-07     NaN
# 2000-01-08     NaN
# 2000-01-09    30.0
# 2000-01-10     NaN
# 2000-01-11     NaN
# 2000-01-12     NaN
# 2000-01-13     NaN
# 2000-01-14     NaN
# 2000-01-15     NaN
# 2000-01-16    40.0
# Freq: D, Name: Price, dtype: float64

# %%
#faster the groupby : sort = False
#data_groups = data1.groupby("Agency", sort=False)
#pour les grs dataset
